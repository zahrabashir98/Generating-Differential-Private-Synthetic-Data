# %% [markdown]
# #CODE for DPGAN
# ## Refrences:
#
# https://blog.tensorflow.org/2019/03/introducing-tensorflow-privacy-learning.html
#
# http://www.cleverhans.io/privacy/2019/03/26/machine-learning-with-differential-privacy-in-tensorflow.html
#
# https://medium.com/gretel-ai/using-generative-differentially-private-models-to-build-privacy-enhancing-synthetic-datasets-c0633856184
#
#
# https://github.com/ricardocarvalhods/dpcgan/blob/master/DP_CGAN_MNIST.ipynb
#
# https://colab.research.google.com/github/ricardocarvalhods/dpcgan/blob/master/DP_CGAN_MNIST.ipynb

# %% [markdown]
# # Loading the Credit Cart Fraud Detection
# (results are not included for this dataset)
# ** please do not run this cell

# %%
from pandas import read_csv
dataframe = read_csv('/content/drive/MyDrive/Privacy/creditcard.csv', header=None)


# load the dataset
def load_dataset(full_path = '/content/drive/MyDrive/Privacy/creditcard.csv'):
	# load the dataset as a numpy array
	data = read_csv(full_path, header=None)
	# retrieve numpy array
	data = data.values
	# split into input and output elements
	X, y = data[:, :-1], data[:, -1]
	return X, y

X, y = load_dataset()
print(X[1:2],y[1:2])

import numpy as np
train_labels = y.reshape((284807, 1))
COND_num_classes = 2 # Number of classes
train_labels_vec = np.zeros((len(train_labels), COND_num_classes), dtype='float32')
for i, label in enumerate(train_labels):
    train_labels_vec[i, int(train_labels[i])] = 1.0

train_data = X.astype('float32')
print(train_data.shape,train_labels_vec.shape)

# %% [markdown]
# # Loading the train real dataset (Banknote Authentication Dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'''

#CODE for DPGAN
## Refrences: 

https://blog.tensorflow.org/2019/03/introducing-tensorflow-privacy-learning.html

http://www.cleverhans.io/privacy/2019/03/26/machine-learning-with-differential-privacy-in-tensorflow.html

https://medium.com/gretel-ai/using-generative-differentially-private-models-to-build-privacy-enhancing-synthetic-datasets-c0633856184


https://github.com/ricardocarvalhods/dpcgan/blob/master/DP_CGAN_MNIST.ipynb

https://colab.research.google.com/github/ricardocarvalhods/dpcgan/blob/master/DP_CGAN_MNIST.ipynb
'''


# load the dataset
from pandas import read_csv
from scipy.special import expit
from sklearn.utils import shuffle
import pickle
def load_dataset(full_path = '/content/drive/MyDrive/Privacy/real_data_train.csv'):
  # load the dataset as a numpy array
  with open(full_path, 'rb') as f:
    data = pickle.load(f)
  print(data)
  # retrieve numpy array
  data = data.values
  # split into input and output elements
  X, y = data[:, :-1], data[:, -1]
  return X, y

X, y = load_dataset()
X = expit(X)
X, y = shuffle(X, y)
print(X.shape,y.shape)
print(X[0])
# Out:
#             0        1         2        3  4
# 131   5.13020   8.6703  -2.89130 -1.50860  0
# 610  -0.23610   9.3221   2.13070 -4.37930  0
# 1314 -3.50600 -12.5667  15.16060 -0.75216  1
# 990  -4.57700   3.4515   0.66719 -0.94742  1
# 292   4.13490   6.1189  -2.42940 -0.19613  0
# ...       ...      ...       ...      ... ..
# 717   2.98560   7.2673  -0.40900 -2.24310  0
# 87    0.87603   6.8141   0.84198 -0.17156  0
# 986   0.84546   3.4826  -3.63070 -1.39610  1
# 1027  0.11686   3.7350  -4.43790 -4.37410  1
# 1013 -0.50816   2.8680  -1.81080 -2.26120  1
#
# [1000 rows x 5 columns]
# (1000, 4) (1000,)
# [0.19190177 0.19278725 0.89229492 0.60364356]

# %%
import numpy as np

train_labels = y.reshape((1000, 1))
COND_num_classes = 2 # Number of classes
train_labels_vec = np.zeros((len(train_labels), COND_num_classes), dtype='float32')
for i, label in enumerate(train_labels):
    train_labels_vec[i, int(train_labels[i])] = 1.0

train_data = X.astype('float32')
print(train_data.shape,train_labels_vec.shape)
# Out:
# (1000, 4) (1000, 2)

# %%
# !pip install tensorflow_privacy
# !pip install sklearn
# Out:
# Requirement already satisfied: tensorflow_privacy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow_privacy) (0.1.6)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.7/dist-packages (from tensorflow_privacy) (1.2.1)
# Requirement already satisfied: tensorflow-estimator>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_privacy) (2.4.0)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.7/dist-packages (from tensorflow_privacy) (1.4.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from dm-tree~=0.1.1->tensorflow_privacy) (1.15.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy>=0.17->tensorflow_privacy) (1.19.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
import tensorflow as tf
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers, models
import tensorflow.keras.backend as K
import time

from IPython import display

from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy
from tensorflow_privacy.privacy.optimizers.dp_optimizer import DPGradientDescentGaussianOptimizer


from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import roc_curve, auc
ConvergenceWarning('ignore')
# Out:
# sklearn.exceptions.ConvergenceWarning('ignore')

# %% [markdown]
# # Model and optimizer setting

# %%
from absl import logging
import collections

from tensorflow_privacy.privacy.analysis import privacy_ledger
from tensorflow_privacy.privacy.dp_query import gaussian_query

def make_optimizer_class(cls):
  """Constructs a DP optimizer class from an existing one."""
  parent_code = tf.compat.v1.train.Optimizer.compute_gradients.__code__
  child_code = cls.compute_gradients.__code__
  GATE_OP = tf.compat.v1.train.Optimizer.GATE_OP  # pylint: disable=invalid-name
  if child_code is not parent_code:
    logging.warning(
        'WARNING: Calling make_optimizer_class() on class %s that overrides '
        'method compute_gradients(). Check to ensure that '
        'make_optimizer_class() does not interfere with overridden version.',
        cls.__name__)

  class DPOptimizerClass(cls):
    """Differentially private subclass of given class cls."""

    _GlobalState = collections.namedtuple(
      '_GlobalState', ['l2_norm_clip', 'stddev'])
    
    def __init__(
        self,
        dp_sum_query,
        num_microbatches=None,
        unroll_microbatches=False,
        *args,  # pylint: disable=keyword-arg-before-vararg, g-doc-args
        **kwargs):
      """Initialize the DPOptimizerClass.

      Args:
        dp_sum_query: DPQuery object, specifying differential privacy
          mechanism to use.
        num_microbatches: How many microbatches into which the minibatch is
          split. If None, will default to the size of the minibatch, and
          per-example gradients will be computed.
        unroll_microbatches: If true, processes microbatches within a Python
          loop instead of a tf.while_loop. Can be used if using a tf.while_loop
          raises an exception.
      """
      super(DPOptimizerClass, self).__init__(*args, **kwargs)
      self._dp_sum_query = dp_sum_query
      self._num_microbatches = num_microbatches
      self._global_state = self._dp_sum_query.initial_global_state()

      self._unroll_microbatches = unroll_microbatches

    def compute_gradients(self,
                          loss,
                          var_list,
                          gate_gradients=GATE_OP,
                          aggregation_method=None,
                          colocate_gradients_with_ops=False,
                          grad_loss=None,
                          gradient_tape=None,
                          curr_noise_mult=0,
                          curr_norm_clip=1):

      self._dp_sum_query = gaussian_query.GaussianSumQuery(curr_norm_clip, 
                                                           curr_norm_clip*curr_noise_mult)
      self._global_state = self._dp_sum_query.make_global_state(curr_norm_clip, 
                                                                curr_norm_clip*curr_noise_mult)
      

      # TF is running in Eager mode, check we received a vanilla tape.
      if not gradient_tape:
        raise ValueError('When in Eager mode, a tape needs to be passed.')

      vector_loss = loss()
      if self._num_microbatches is None:
        self._num_microbatches = tf.shape(input=vector_loss)[0]
      sample_state = self._dp_sum_query.initial_sample_state(var_list)
      microbatches_losses = tf.reshape(vector_loss, [self._num_microbatches, -1])
      sample_params = (self._dp_sum_query.derive_sample_params(self._global_state))

      def process_microbatch(i, sample_state):
        """Process one microbatch (record) with privacy helper."""
        microbatch_loss = tf.reduce_mean(input_tensor=tf.gather(microbatches_losses, [i]))
        grads = gradient_tape.gradient(microbatch_loss, var_list)
        sample_state = self._dp_sum_query.accumulate_record(sample_params, sample_state, grads)
        return sample_state
    
      for idx in range(self._num_microbatches):
        sample_state = process_microbatch(idx, sample_state)

      if curr_noise_mult > 0:
        grad_sums, self._global_state = (self._dp_sum_query.get_noised_result(sample_state, self._global_state))
      else:
        grad_sums = sample_state

      def normalize(v):
        return v / tf.cast(self._num_microbatches, tf.float32)

      final_grads = tf.nest.map_structure(normalize, grad_sums)
      grads_and_vars = final_grads#list(zip(final_grads, var_list))
    
      return grads_and_vars

  return DPOptimizerClass


def make_gaussian_optimizer_class(cls):
  """Constructs a DP optimizer with Gaussian averaging of updates."""

  class DPGaussianOptimizerClass(make_optimizer_class(cls)):
    """DP subclass of given class cls using Gaussian averaging."""

    def __init__(
        self,
        l2_norm_clip,
        noise_multiplier,
        num_microbatches=None,
        ledger=None,
        unroll_microbatches=False,
        *args,  # pylint: disable=keyword-arg-before-vararg
        **kwargs):
      dp_sum_query = gaussian_query.GaussianSumQuery(
          l2_norm_clip, l2_norm_clip * noise_multiplier)

      if ledger:
        dp_sum_query = privacy_ledger.QueryWithLedger(dp_sum_query,
                                                      ledger=ledger)

      super(DPGaussianOptimizerClass, self).__init__(
          dp_sum_query,
          num_microbatches,
          unroll_microbatches,
          *args,
          **kwargs)

    @property
    def ledger(self):
      return self._dp_sum_query.ledger

  return DPGaussianOptimizerClass

# %%
GradientDescentOptimizer = tf.compat.v1.train.GradientDescentOptimizer
DPGradientDescentGaussianOptimizer_NEW = make_gaussian_optimizer_class(GradientDescentOptimizer)

# %%
# Edit to define folder
result_dir = '/content/drive/MyDrive/Privacy'

# DO NOT EDIT THIS CELL

# Define checkpoint dir and prefix
checkpoint_dir = result_dir + '/training_checkpoints_NEW_DPGAN'

def checkpoint_name(title):  
  checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt__" + title)
  return(checkpoint_prefix)

# %%
# Dimension of Latent Space - Does NOT affect DP-EPSILON
Z_DIM = 4
#noisy nput vector

# %% [markdown]
# However, to implement WGAN, we should notice few things from the above:
#
# No
# log
#  in the loss. The output of
# D
#  is no longer a probability, hence we do not apply sigmoid at the output of
# D
# Clip the weight of
# D
# Train
# D
#  more than
# G
# Use RMSProp instead of ADAM
# Lower learning rate, the paper uses
# α
# =
# 0.00005

# %%
#define the conditional GAN
def make_generator_model_FCC():
    # INPUT: label input
    # in_label = layers.Input(shape=(COND_num_classes,))

    # INPUT: data generator input
    in_lat = layers.Input(shape=(Z_DIM,))

    # MERGE
    # merge = layers.concatenate([in_lat, in_label], axis=1)

    ge1 = layers.Dense(20, use_bias=True)(in_lat)
    ge1 = layers.ReLU()(ge1)


    ge3 = layers.Dense(4, use_bias=True, activation="tanh")(ge1)
    out_layer = layers.Reshape((4,))(ge3)

    model = models.Model(in_lat, out_layer)

    return model

def make_discriminator_model_FCC():
    # INPUT: Label
    # in_label = layers.Input(shape=(COND_num_classes,))

    # INPUT: data
    in_data = layers.Input(shape=(4,))
    # in_data_b = layers.Flatten()(in_data)

    # MERGE
    # merge = layers.concatenate([in_data, in_label], axis=1)

    di1 = layers.Dense(20, use_bias=True)(in_data)
    di1 = layers.ReLU()(di1)

    di2 = layers.Dense(4, use_bias=True)(di1)
    di2 = layers.ReLU()(di2)

    out_layer = layers.Dense(1, use_bias=True)(di2)

    model = models.Model(in_data, out_layer)

    return model

# %%
generator = make_generator_model_FCC()
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 4)]               0
# _________________________________________________________________
# dense (Dense)                (None, 20)                100
# _________________________________________________________________
# re_lu (ReLU)                 (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 84
# _________________________________________________________________
# reshape (Reshape)            (None, 4)                 0
# =================================================================
# Total params: 184
# Trainable params: 184
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator = make_discriminator_model_FCC()
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 4)]               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                100
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 20)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 84
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 4)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 189
# Trainable params: 189
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Test GEN created
noise = tf.Variable(tf.random.normal([1, Z_DIM]))
# noise_label = tf.Variable(np.array([0,1], dtype='float32').reshape((1,2)))
print(noise.shape)
# print(noise_label.shape)
generated_data = generator(noise, training=False)
print(generated_data)

decision = discriminator(generated_data)
print("decision",decision)
# Out:
# (1, 4)
# tf.Tensor([[ 0.03868612 -0.00282908 -0.00720142 -0.22596738]], shape=(1, 4), dtype=float32)
# decision tf.Tensor([[0.12446492]], shape=(1, 1), dtype=float32)

# %% [markdown]
# # Update

# %%
cross_entropy_DISC = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.losses.Reduction.NONE)
cross_entropy_GEN = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Notice the use of `tf.function`: This annotation causes the function to be "compiled".
@tf.function
def train_step_DISC(datas, noise):    
    with tf.GradientTape(persistent=True) as disc_tape_real:
        # This dummy call is needed to obtain the var list.
        dummy = discriminator(datas, training=True)
        var_list = discriminator.trainable_variables
        
        # In Eager mode, the optimizer takes a function that returns the loss.
        def loss_fn_real():
            real_output = discriminator(datas, training=True)
            disc_real_loss = cross_entropy_DISC(tf.ones_like(real_output), real_output)
            return disc_real_loss
        
        grads_and_vars_real = discriminator_optimizer.compute_gradients(loss_fn_real, 
                                                                        var_list, 
                                                                        gradient_tape=disc_tape_real, 
                                                                        curr_noise_mult=NOISE_MULT,
                                                                        curr_norm_clip=NORM_CLIP)
        
        # In Eager mode, the optimizer takes a function that returns the loss.
        def loss_fn_fake():
            generated_datas = generator(noise, training=True)
            fake_output = discriminator(generated_datas, training=True)
            disc_fake_loss = cross_entropy_DISC(tf.zeros_like(fake_output), fake_output)
            return disc_fake_loss
        
        grads_and_vars_fake = discriminator_optimizer.compute_gradients(loss_fn_fake,
                                                                        var_list, 
                                                                        gradient_tape=disc_tape_real,
                                                                        curr_noise_mult=0,
                                                                        curr_norm_clip=NORM_CLIP)
        disc_loss_r = loss_fn_real()
        disc_loss_f = loss_fn_fake()
        
        s_grads_and_vars = [(grads_and_vars_real[idx] + grads_and_vars_fake[idx])
                            for idx in range(len(grads_and_vars_real))]
        sanitized_grads_and_vars = list(zip(s_grads_and_vars, var_list))
        
        discriminator_optimizer.apply_gradients(sanitized_grads_and_vars)

    return(disc_loss_r, disc_loss_f)

# Notice the use of `tf.function`: This annotation causes the function to be "compiled".
@tf.function
def train_step_GEN(noise):
    with tf.GradientTape() as gen_tape:
        generated_datas = generator(noise, training=True)
        fake_output = discriminator(generated_datas, training=True)
        # if the generator is performing well, the discriminator will classify the fake datas as real (or 1)
        gen_loss = cross_entropy_GEN(tf.ones_like(fake_output), fake_output)
        
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    
    return(gen_loss)

# %% [markdown]
# #Train

# %%
def train(dataset, title, verbose):
    for epoch in range(EPOCHS):
        start = time.time()

        i_gen = 0
        for data_batch in dataset:
            if verbose:
                print("Iteration: " + str(i_gen+1))
            
            noise = tf.random.normal([BATCH_SIZE, Z_DIM])
            # labels_to_gen = _random_choice(labels_gen_vec, BATCH_SIZE)
    
            d_loss_r, d_loss_f = train_step_DISC(data_batch, noise)
            if verbose:
                print("Loss DISC Real: " + str(tf.reduce_mean(d_loss_r)))
                print("Loss DISC Fake: " + str(tf.reduce_mean(d_loss_f)))

            if (i_gen + 1) % N_DISC == 0:
                g_loss_f = train_step_GEN(noise)
                if verbose:
                    print("Loss GEN Fake:: " + str(g_loss_f))

            i_gen = i_gen + 1

        print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))
        print(epoch)
        print("end of epoch")

        # Save the model
        # checkpoint.save("/content/drive/MyDrive/Privacy/training_checkpoints/positive_model" + str(epoch))
        checkpoint.save(file_prefix = checkpoint_name(title + "__epoch=" + str(epoch) + "__"))

# %% [markdown]
# # parameters setting

# %%
BUFFER_SIZE = 1000 # Total size of training data
BATCH_SIZE = 10
NR_MICROBATCHES = 1 # Each batch of data is split in smaller units called microbatches.


NORM_CLIP = 1.1 # Does NOT affect EPSILON, but increases NOISE on gradients
NOISE_MULT = 1.15


DP_DELTA = 1e-5 # Needs to be smaller than 1/BUFFER_SIZE
EPOCHS = 1000


N_DISC = 1 # Number of times we train DISC before training GEN once


# Learning Rate for DISCRIMINATOR
LR_DISC = tf.compat.v1.train.polynomial_decay(learning_rate=0.150,
                                              global_step=tf.compat.v1.train.get_or_create_global_step(),
                                              decay_steps=10000,
                                              end_learning_rate=0.052,
                                              power=1)

if BATCH_SIZE % NR_MICROBATCHES != 0:
    raise ValueError('Batch size should be an integer multiple of the number of microbatches')

# %%
# Obtain DP_EPSILON
compute_dp_sgd_privacy.compute_dp_sgd_privacy(n = BUFFER_SIZE, 
                                              batch_size = BATCH_SIZE, 
                                              noise_multiplier = NOISE_MULT, 
                                              epochs = EPOCHS, 
                                              delta = DP_DELTA)
# Out:
# DP-SGD with sampling rate = 1% and noise_multiplier = 1.15 iterated over 100000 steps satisfies differential privacy with eps = 20.7 and delta = 1e-05.
# The optimal RDP order is 2.25.
# (20.734201516946577, 2.25)

# %%
# SD of noise that will be added to gradients: sanity check
NOISE_MULT*NORM_CLIP
# Out:
# 1.265

# %% [markdown]
# #Optimizer

# %%
generator_optimizer = tf.keras.optimizers.Adam()

discriminator_optimizer = DPGradientDescentGaussianOptimizer_NEW(
   learning_rate = LR_DISC,
   l2_norm_clip = NORM_CLIP,
   noise_multiplier = NOISE_MULT,
   num_microbatches = NR_MICROBATCHES)

# %% [markdown]
# # Training process

# %%
# Create/reinitiate models
generator = make_generator_model_FCC()
discriminator = make_discriminator_model_FCC()

# %%
# Create checkpoint structure
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
tf.random.set_seed(1)

# Batch and random shuffle training data
train_dataset = tf.data.Dataset.from_tensor_slices(train_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Fix some seeds to help visualize progress
seed = tf.random.normal([2, Z_DIM])

# %% [markdown]
# # GAN for negative

# %%
negative =[]
positive = []

for k in range(0,len(y)):
  if y[k]==0.0:
    negative.append(X[k])
  else:
    positive.append(X[k])

# %%
negative = np.array(negative)
print(negative.shape)   
print(negative[1])
# Out:
# (561, 4)
# [0.97104697 0.94820612 0.74228903 0.60054585]

# %% [markdown]
# # train GAN for negative

# %%
tf.random.set_seed(100)

# Batch and random shuffle training data
train_dataset_neg = tf.data.Dataset.from_tensor_slices(negative).shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
# train(train_dataset_neg, "neg", False)

# %% [markdown]
# ## restore model , generate and save data

# %%
title = "neg"
epoch_ckp = EPOCHS - 1

# %%
# DO NOT EDIT
checkpoint_name = checkpoint_dir + "/ckpt__" + str(title) + "__epoch=" + str(19) + "__-" + str(20)

# RESTORE CHECKPOINT to variables defined on it
checkpoint.restore(checkpoint_name)

# %%
# Number of neg data to generate
N_neg = 500

# %%
Z_DIM=4
tf.random.set_seed(0)
noise_GEN = tf.random.normal([N_neg, Z_DIM])
# labels_GEN = set for CGAN
data_neg_GEN = generator(noise_GEN, training=False)

# %%
import numpy
proto_tensor = tf.make_tensor_proto(data_neg_GEN)  # convert `tensor a` to a proto tensor
data = tf.make_ndarray(proto_tensor) #convert tf tesor to np array
print(data.shape)

# %%
import pandas as pd 
pd.DataFrame(data).to_csv("/content/drive/MyDrive/Privacy/DPGAN_neg_NEWdata.csv")
# numpy.savetxt("/content/drive/MyDrive/Privacy/DPGAN_neg_data.csv", data, delimiter=",")

# %% [markdown]
# # repeat for positive data

# %%
positive = np.array(positive)
print(positive.shape)
# Out:
# (439, 4)

# %%
tf.random.set_seed(0)

# Batch and random shuffle training data
train_dataset_pos = tf.data.Dataset.from_tensor_slices(positive).shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
train(train_dataset_pos, "positive_data", False)
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Time for epoch 1 is 2.0329301357269287 sec
# 0
# end of epoch
# Time for epoch 2 is 0.07017159461975098 sec
# 1
# end of epoch
# Time for epoch 3 is 0.06985855102539062 sec
# 2
# end of epoch
# Time for epoch 4 is 0.07195663452148438 sec
# 3
# end of epoch
# Time for epoch 5 is 0.0706939697265625 sec
# 4
# end of epoch
# Time for epoch 6 is 0.07299995422363281 sec
# 5
# end of epoch
# Time for epoch 7 is 0.07415270805358887 sec
# 6
# end of epoch
# Time for epoch 8 is 0.07168102264404297 sec
# 7
# end of epoch
# Time for epoch 9 is 0.07899355888366699 sec
# 8
# end of epoch
# Time for epoch 10 is 0.08603143692016602 sec
# 9
# end of epoch
# Time for epoch 11 is 0.08832859992980957 sec
# 10
# end of epoch
# Time for epoch 12 is 0.07544207572937012 sec
# 11
# end of epoch
# Time for epoch 13 is 0.07108688354492188 sec
# 12
# end of epoch
# Time for epoch 14 is 0.07173371315002441 sec
# 13
# end of epoch
# Time for epoch 15 is 0.07080245018005371 sec
# 14
# end of epoch
# Time for epoch 16 is 0.07403826713562012 sec
# 15
# end of epoch
# Time for epoch 17 is 0.0732719898223877 sec
# 16
# end of epoch
# Time for epoch 18 is 0.07362651824951172 sec
# 17
# end of epoch
# Time for epoch 19 is 0.07313823699951172 sec
# 18
# end of epoch
# Time for epoch 20 is 0.06961679458618164 sec
# 19
# end of epoch
# Time for epoch 21 is 0.07434344291687012 sec
# 20
# end of epoch
# Time for epoch 22 is 0.07294535636901855 sec
# 21
# end of epoch
# Time for epoch 23 is 0.07313299179077148 sec
# 22
# end of epoch
# Time for epoch 24 is 0.07721138000488281 sec
# 23
# end of epoch
# Time for epoch 25 is 0.07726383209228516 sec
# 24
# end of epoch
# Time for epoch 26 is 0.07639265060424805 sec
# 25
# end of epoch
# Time for epoch 27 is 0.07252645492553711 sec
# 26
# end of epoch
# Time for epoch 28 is 0.0840606689453125 sec
# 27
# end of epoch
# Time for epoch 29 is 0.07306170463562012 sec
# 28
# end of epoch
# Time for epoch 30 is 0.07257246971130371 sec
# 29
# end of epoch
# Time for epoch 31 is 0.07083606719970703 sec
# 30
# end of epoch
# Time for epoch 32 is 0.07048964500427246 sec
# 31
# end of epoch
# Time for epoch 33 is 0.0761878490447998 sec
# 32
# end of epoch
# Time for epoch 34 is 0.08221673965454102 sec
# 33
# end of epoch
# Time for epoch 35 is 0.07071280479431152 sec
# 34
# end of epoch
# Time for epoch 36 is 0.0735464096069336 sec
# 35
# end of epoch
# Time for epoch 37 is 0.06874942779541016 sec
# 36
# end of epoch
# Time for epoch 38 is 0.07321500778198242 sec
# 37
# end of epoch
# Time for epoch 39 is 0.07035255432128906 sec
# 38
# end of epoch
# Time for epoch 40 is 0.07564210891723633 sec
# 39
# end of epoch
# Time for epoch 41 is 0.07008075714111328 sec
# 40
# end of epoch
# Time for epoch 42 is 0.07551360130310059 sec
# 41
# end of epoch
# Time for epoch 43 is 0.08189702033996582 sec
# 42
# end of epoch
# Time for epoch 44 is 0.07104969024658203 sec
# 43
# end of epoch
# Time for epoch 45 is 0.06828761100769043 sec
# 44
# end of epoch
# Time for epoch 46 is 0.07510638236999512 sec
# 45
# end of epoch
# Time for epoch 47 is 0.07098507881164551 sec
# 46
# end of epoch
# Time for epoch 48 is 0.07990431785583496 sec
# 47
# end of epoch
# Time for epoch 49 is 0.0688474178314209 sec
# 48
# end of epoch
# Time for epoch 50 is 0.08328533172607422 sec
# 49
# end of epoch
# Time for epoch 51 is 0.0699622631072998 sec
# 50
# end of epoch
# Time for epoch 52 is 0.07357287406921387 sec
# 51
# end of epoch
# Time for epoch 53 is 0.06776237487792969 sec
# 52
# end of epoch
# Time for epoch 54 is 0.07280755043029785 sec
# 53
# end of epoch
# Time for epoch 55 is 0.0688478946685791 sec
# 54
# end of epoch
# Time for epoch 56 is 0.07360267639160156 sec
# 55
# end of epoch
# Time for epoch 57 is 0.07967090606689453 sec
# 56
# end of epoch
# Time for epoch 58 is 0.06993913650512695 sec
# 57
# end of epoch
# Time for epoch 59 is 0.07991194725036621 sec
# 58
# end of epoch
# Time for epoch 60 is 0.07173871994018555 sec
# 59
# end of epoch
# Time for epoch 61 is 0.0701603889465332 sec
# 60
# end of epoch
# Time for epoch 62 is 0.06931829452514648 sec
# 61
# end of epoch
# Time for epoch 63 is 0.07156777381896973 sec
# 62
# end of epoch
# Time for epoch 64 is 0.07547473907470703 sec
# 63
# end of epoch
# Time for epoch 65 is 0.07394051551818848 sec
# 64
# end of epoch
# Time for epoch 66 is 0.07483983039855957 sec
# 65
# end of epoch
# Time for epoch 67 is 0.06969380378723145 sec
# 66
# end of epoch
# Time for epoch 68 is 0.07596278190612793 sec
# 67
# end of epoch
# Time for epoch 69 is 0.0710146427154541 sec
# 68
# end of epoch
# Time for epoch 70 is 0.07161784172058105 sec
# 69
# end of epoch
# Time for epoch 71 is 0.07503962516784668 sec
# 70
# end of epoch
# Time for epoch 72 is 0.06810617446899414 sec
# 71
# end of epoch
# Time for epoch 73 is 0.06999874114990234 sec
# 72
# end of epoch
# Time for epoch 74 is 0.08145689964294434 sec
# 73
# end of epoch
# Time for epoch 75 is 0.06964850425720215 sec
# 74
# end of epoch
# Time for epoch 76 is 0.06977605819702148 sec
# 75
# end of epoch
# Time for epoch 77 is 0.07414817810058594 sec
# 76
# end of epoch
# Time for epoch 78 is 0.09192514419555664 sec
# 77
# end of epoch
# Time for epoch 79 is 0.07746529579162598 sec
# 78
# end of epoch
# Time for epoch 80 is 0.0821225643157959 sec
# 79
# end of epoch
# Time for epoch 81 is 0.08403563499450684 sec
# 80
# end of epoch
# Time for epoch 82 is 0.07187223434448242 sec
# 81
# end of epoch
# Time for epoch 83 is 0.07106709480285645 sec
# 82
# end of epoch
# Time for epoch 84 is 0.07729411125183105 sec
# 83
# end of epoch
# Time for epoch 85 is 0.06944918632507324 sec
# 84
# end of epoch
# Time for epoch 86 is 0.0701606273651123 sec
# 85
# end of epoch
# Time for epoch 87 is 0.07253003120422363 sec
# 86
# end of epoch
# Time for epoch 88 is 0.07723498344421387 sec
# 87
# end of epoch
# Time for epoch 89 is 0.07224917411804199 sec
# 88
# end of epoch
# Time for epoch 90 is 0.07559847831726074 sec
# 89
# end of epoch
# Time for epoch 91 is 0.07386016845703125 sec
# 90
# end of epoch
# Time for epoch 92 is 0.08658361434936523 sec
# 91
# end of epoch
# Time for epoch 93 is 0.08050322532653809 sec
# 92
# end of epoch
# Time for epoch 94 is 0.07581758499145508 sec
# 93
# end of epoch
# Time for epoch 95 is 0.08263564109802246 sec
# 94
# end of epoch
# Time for epoch 96 is 0.08003425598144531 sec
# 95
# end of epoch
# Time for epoch 97 is 0.07396078109741211 sec
# 96
# end of epoch
# Time for epoch 98 is 0.07049965858459473 sec
# 97
# end of epoch
# Time for epoch 99 is 0.0711057186126709 sec
# 98
# end of epoch
# Time for epoch 100 is 0.07906365394592285 sec
# 99
# end of epoch
# Time for epoch 101 is 0.07017326354980469 sec
# 100
# end of epoch
# Time for epoch 102 is 0.06933450698852539 sec
# 101
# end of epoch
# Time for epoch 103 is 0.0710294246673584 sec
# 102
# end of epoch
# Time for epoch 104 is 0.07009649276733398 sec
# 103
# end of epoch
# Time for epoch 105 is 0.06872844696044922 sec
# 104
# end of epoch
# Time for epoch 106 is 0.07054257392883301 sec
# 105
# end of epoch
# Time for epoch 107 is 0.07644486427307129 sec
# 106
# end of epoch
# Time for epoch 108 is 0.07238340377807617 sec
# 107
# end of epoch
# Time for epoch 109 is 0.07235002517700195 sec
# 108
# end of epoch
# Time for epoch 110 is 0.06818771362304688 sec
# 109
# end of epoch
# Time for epoch 111 is 0.0703728199005127 sec
# 110
# end of epoch
# Time for epoch 112 is 0.07068181037902832 sec
# 111
# end of epoch
# Time for epoch 113 is 0.08096933364868164 sec
# 112
# end of epoch
# Time for epoch 114 is 0.07636666297912598 sec
# 113
# end of epoch
# Time for epoch 115 is 0.07808160781860352 sec
# 114
# end of epoch
# Time for epoch 116 is 0.0770423412322998 sec
# 115
# end of epoch
# Time for epoch 117 is 0.093475341796875 sec
# 116
# end of epoch
# Time for epoch 118 is 0.06929922103881836 sec
# 117
# end of epoch
# Time for epoch 119 is 0.06855201721191406 sec
# 118
# end of epoch
# Time for epoch 120 is 0.0906682014465332 sec
# 119
# end of epoch
# Time for epoch 121 is 0.08285856246948242 sec
# 120
# end of epoch
# Time for epoch 122 is 0.07952713966369629 sec
# 121
# end of epoch
# Time for epoch 123 is 0.06883049011230469 sec
# 122
# end of epoch
# Time for epoch 124 is 0.09207510948181152 sec
# 123
# end of epoch
# Time for epoch 125 is 0.08200812339782715 sec
# 124
# end of epoch
# Time for epoch 126 is 0.0746164321899414 sec
# 125
# end of epoch
# Time for epoch 127 is 0.0858151912689209 sec
# 126
# end of epoch
# Time for epoch 128 is 0.07752299308776855 sec
# 127
# end of epoch
# Time for epoch 129 is 0.07807135581970215 sec
# 128
# end of epoch
# Time for epoch 130 is 0.07103133201599121 sec
# 129
# end of epoch
# Time for epoch 131 is 0.06884479522705078 sec
# 130
# end of epoch
# Time for epoch 132 is 0.08307743072509766 sec
# 131
# end of epoch
# Time for epoch 133 is 0.07204413414001465 sec
# 132
# end of epoch
# Time for epoch 134 is 0.07621312141418457 sec
# 133
# end of epoch
# Time for epoch 135 is 0.07738876342773438 sec
# 134
# end of epoch
# Time for epoch 136 is 0.07198214530944824 sec
# 135
# end of epoch
# Time for epoch 137 is 0.08107280731201172 sec
# 136
# end of epoch
# Time for epoch 138 is 0.07293510437011719 sec
# 137
# end of epoch
# Time for epoch 139 is 0.06821012496948242 sec
# 138
# end of epoch
# Time for epoch 140 is 0.06899213790893555 sec
# 139
# end of epoch
# Time for epoch 141 is 0.07195782661437988 sec
# 140
# end of epoch
# Time for epoch 142 is 0.06940102577209473 sec
# 141
# end of epoch
# Time for epoch 143 is 0.071624755859375 sec
# 142
# end of epoch
# Time for epoch 144 is 0.07621455192565918 sec
# 143
# end of epoch
# Time for epoch 145 is 0.08089995384216309 sec
# 144
# end of epoch
# Time for epoch 146 is 0.07377314567565918 sec
# 145
# end of epoch
# Time for epoch 147 is 0.08201766014099121 sec
# 146
# end of epoch
# Time for epoch 148 is 0.08012104034423828 sec
# 147
# end of epoch
# Time for epoch 149 is 0.07482409477233887 sec
# 148
# end of epoch
# Time for epoch 150 is 0.0716090202331543 sec
# 149
# end of epoch
# Time for epoch 151 is 0.07248497009277344 sec
# 150
# end of epoch
# Time for epoch 152 is 0.07120728492736816 sec
# 151
# end of epoch
# Time for epoch 153 is 0.07607126235961914 sec
# 152
# end of epoch
# Time for epoch 154 is 0.07365536689758301 sec
# 153
# end of epoch
# Time for epoch 155 is 0.07542037963867188 sec
# 154
# end of epoch
# Time for epoch 156 is 0.08516931533813477 sec
# 155
# end of epoch
# Time for epoch 157 is 0.07967448234558105 sec
# 156
# end of epoch
# Time for epoch 158 is 0.08324122428894043 sec
# 157
# end of epoch
# Time for epoch 159 is 0.08268260955810547 sec
# 158
# end of epoch
# Time for epoch 160 is 0.07943487167358398 sec
# 159
# end of epoch
# Time for epoch 161 is 0.07240128517150879 sec
# 160
# end of epoch
# Time for epoch 162 is 0.07321286201477051 sec
# 161
# end of epoch
# Time for epoch 163 is 0.07183957099914551 sec
# 162
# end of epoch
# Time for epoch 164 is 0.06975507736206055 sec
# 163
# end of epoch
# Time for epoch 165 is 0.0715489387512207 sec
# 164
# end of epoch
# Time for epoch 166 is 0.07521820068359375 sec
# 165
# end of epoch
# Time for epoch 167 is 0.08329105377197266 sec
# 166
# end of epoch
# Time for epoch 168 is 0.09448623657226562 sec
# 167
# end of epoch
# Time for epoch 169 is 0.0744936466217041 sec
# 168
# end of epoch
# Time for epoch 170 is 0.07190728187561035 sec
# 169
# end of epoch
# Time for epoch 171 is 0.07157421112060547 sec
# 170
# end of epoch
# Time for epoch 172 is 0.07112979888916016 sec
# 171
# end of epoch
# Time for epoch 173 is 0.07679438591003418 sec
# 172
# end of epoch
# Time for epoch 174 is 0.07475709915161133 sec
# 173
# end of epoch
# Time for epoch 175 is 0.07061529159545898 sec
# 174
# end of epoch
# Time for epoch 176 is 0.07004261016845703 sec
# 175
# end of epoch
# Time for epoch 177 is 0.0741417407989502 sec
# 176
# end of epoch
# Time for epoch 178 is 0.07360386848449707 sec
# 177
# end of epoch
# Time for epoch 179 is 0.0700674057006836 sec
# 178
# end of epoch
# Time for epoch 180 is 0.07535433769226074 sec
# 179
# end of epoch
# Time for epoch 181 is 0.06869864463806152 sec
# 180
# end of epoch
# Time for epoch 182 is 0.07195830345153809 sec
# 181
# end of epoch
# Time for epoch 183 is 0.07924985885620117 sec
# 182
# end of epoch
# Time for epoch 184 is 0.07654881477355957 sec
# 183
# end of epoch
# Time for epoch 185 is 0.07013440132141113 sec
# 184
# end of epoch
# Time for epoch 186 is 0.07977724075317383 sec
# 185
# end of epoch
# Time for epoch 187 is 0.08011984825134277 sec
# 186
# end of epoch
# Time for epoch 188 is 0.07096695899963379 sec
# 187
# end of epoch
# Time for epoch 189 is 0.07197022438049316 sec
# 188
# end of epoch
# Time for epoch 190 is 0.07034730911254883 sec
# 189
# end of epoch
# Time for epoch 191 is 0.07673788070678711 sec
# 190
# end of epoch
# Time for epoch 192 is 0.07026195526123047 sec
# 191
# end of epoch
# Time for epoch 193 is 0.08379936218261719 sec
# 192
# end of epoch
# Time for epoch 194 is 0.0717918872833252 sec
# 193
# end of epoch
# Time for epoch 195 is 0.0728292465209961 sec
# 194
# end of epoch
# Time for epoch 196 is 0.0758814811706543 sec
# 195
# end of epoch
# Time for epoch 197 is 0.07344865798950195 sec
# 196
# end of epoch
# Time for epoch 198 is 0.08040809631347656 sec
# 197
# end of epoch
# Time for epoch 199 is 0.08476376533508301 sec
# 198
# end of epoch
# Time for epoch 200 is 0.06978607177734375 sec
# 199
# end of epoch
# Time for epoch 201 is 0.07001852989196777 sec
# 200
# end of epoch
# Time for epoch 202 is 0.07009601593017578 sec
# 201
# end of epoch
# Time for epoch 203 is 0.06997084617614746 sec
# 202
# end of epoch
# Time for epoch 204 is 0.06911540031433105 sec
# 203
# end of epoch
# Time for epoch 205 is 0.07867193222045898 sec
# 204
# end of epoch
# Time for epoch 206 is 0.07250404357910156 sec
# 205
# end of epoch
# Time for epoch 207 is 0.06890559196472168 sec
# 206
# end of epoch
# Time for epoch 208 is 0.07089710235595703 sec
# 207
# end of epoch
# Time for epoch 209 is 0.07328987121582031 sec
# 208
# end of epoch
# Time for epoch 210 is 0.0748443603515625 sec
# 209
# end of epoch
# Time for epoch 211 is 0.07134222984313965 sec
# 210
# end of epoch
# Time for epoch 212 is 0.08155250549316406 sec
# 211
# end of epoch
# Time for epoch 213 is 0.0845332145690918 sec
# 212
# end of epoch
# Time for epoch 214 is 0.07118749618530273 sec
# 213
# end of epoch
# Time for epoch 215 is 0.08733487129211426 sec
# 214
# end of epoch
# Time for epoch 216 is 0.07371687889099121 sec
# 215
# end of epoch
# Time for epoch 217 is 0.0851287841796875 sec
# 216
# end of epoch
# Time for epoch 218 is 0.07580232620239258 sec
# 217
# end of epoch
# Time for epoch 219 is 0.08873486518859863 sec
# 218
# end of epoch
# Time for epoch 220 is 0.07363462448120117 sec
# 219
# end of epoch
# Time for epoch 221 is 0.07189369201660156 sec
# 220
# end of epoch
# Time for epoch 222 is 0.08834218978881836 sec
# 221
# end of epoch
# Time for epoch 223 is 0.06972694396972656 sec
# 222
# end of epoch
# Time for epoch 224 is 0.10228133201599121 sec
# 223
# end of epoch
# Time for epoch 225 is 0.0691366195678711 sec
# 224
# end of epoch
# Time for epoch 226 is 0.07159066200256348 sec
# 225
# end of epoch
# Time for epoch 227 is 0.0783395767211914 sec
# 226
# end of epoch
# Time for epoch 228 is 0.08888006210327148 sec
# 227
# end of epoch
# Time for epoch 229 is 0.07811737060546875 sec
# 228
# end of epoch
# Time for epoch 230 is 0.07837891578674316 sec
# 229
# end of epoch
# Time for epoch 231 is 0.08584904670715332 sec
# 230
# end of epoch
# Time for epoch 232 is 0.07227587699890137 sec
# 231
# end of epoch
# Time for epoch 233 is 0.07231354713439941 sec
# 232
# end of epoch
# Time for epoch 234 is 0.07180619239807129 sec
# 233
# end of epoch
# Time for epoch 235 is 0.0765085220336914 sec
# 234
# end of epoch
# Time for epoch 236 is 0.06904816627502441 sec
# 235
# end of epoch
# Time for epoch 237 is 0.08534860610961914 sec
# 236
# end of epoch
# Time for epoch 238 is 0.07676815986633301 sec
# 237
# end of epoch
# Time for epoch 239 is 0.07251310348510742 sec
# 238
# end of epoch
# Time for epoch 240 is 0.07661056518554688 sec
# 239
# end of epoch
# Time for epoch 241 is 0.07142376899719238 sec
# 240
# end of epoch
# Time for epoch 242 is 0.07094097137451172 sec
# 241
# end of epoch
# Time for epoch 243 is 0.07147955894470215 sec
# 242
# end of epoch
# Time for epoch 244 is 0.07546281814575195 sec
# 243
# end of epoch
# Time for epoch 245 is 0.08649492263793945 sec
# 244
# end of epoch
# Time for epoch 246 is 0.0727853775024414 sec
# 245
# end of epoch
# Time for epoch 247 is 0.07250046730041504 sec
# 246
# end of epoch
# Time for epoch 248 is 0.0762946605682373 sec
# 247
# end of epoch
# Time for epoch 249 is 0.07651996612548828 sec
# 248
# end of epoch
# Time for epoch 250 is 0.08530402183532715 sec
# 249
# end of epoch
# Time for epoch 251 is 0.07352304458618164 sec
# 250
# end of epoch
# Time for epoch 252 is 0.07065439224243164 sec
# 251
# end of epoch
# Time for epoch 253 is 0.07615017890930176 sec
# 252
# end of epoch
# Time for epoch 254 is 0.07198905944824219 sec
# 253
# end of epoch
# Time for epoch 255 is 0.06999421119689941 sec
# 254
# end of epoch
# Time for epoch 256 is 0.07902026176452637 sec
# 255
# end of epoch
# Time for epoch 257 is 0.07361459732055664 sec
# 256
# end of epoch
# Time for epoch 258 is 0.06885004043579102 sec
# 257
# end of epoch
# Time for epoch 259 is 0.0811913013458252 sec
# 258
# end of epoch
# Time for epoch 260 is 0.0855402946472168 sec
# 259
# end of epoch
# Time for epoch 261 is 0.07249689102172852 sec
# 260
# end of epoch
# Time for epoch 262 is 0.09086012840270996 sec
# 261
# end of epoch
# Time for epoch 263 is 0.07126188278198242 sec
# 262
# end of epoch
# Time for epoch 264 is 0.07027673721313477 sec
# 263
# end of epoch
# Time for epoch 265 is 0.07110404968261719 sec
# 264
# end of epoch
# Time for epoch 266 is 0.07201814651489258 sec
# 265
# end of epoch
# Time for epoch 267 is 0.07904338836669922 sec
# 266
# end of epoch
# Time for epoch 268 is 0.08187437057495117 sec
# 267
# end of epoch
# Time for epoch 269 is 0.07128119468688965 sec
# 268
# end of epoch
# Time for epoch 270 is 0.07292699813842773 sec
# 269
# end of epoch
# Time for epoch 271 is 0.07118630409240723 sec
# 270
# end of epoch
# Time for epoch 272 is 0.0713644027709961 sec
# 271
# end of epoch
# Time for epoch 273 is 0.06917762756347656 sec
# 272
# end of epoch
# Time for epoch 274 is 0.07217264175415039 sec
# 273
# end of epoch
# Time for epoch 275 is 0.0825798511505127 sec
# 274
# end of epoch
# Time for epoch 276 is 0.07074618339538574 sec
# 275
# end of epoch
# Time for epoch 277 is 0.07478165626525879 sec
# 276
# end of epoch
# Time for epoch 278 is 0.10206484794616699 sec
# 277
# end of epoch
# Time for epoch 279 is 0.07429647445678711 sec
# 278
# end of epoch
# Time for epoch 280 is 0.0867776870727539 sec
# 279
# end of epoch
# Time for epoch 281 is 0.07739090919494629 sec
# 280
# end of epoch
# Time for epoch 282 is 0.08432841300964355 sec
# 281
# end of epoch
# Time for epoch 283 is 0.06969118118286133 sec
# 282
# end of epoch
# Time for epoch 284 is 0.0706477165222168 sec
# 283
# end of epoch
# Time for epoch 285 is 0.07868361473083496 sec
# 284
# end of epoch
# Time for epoch 286 is 0.07806587219238281 sec
# 285
# end of epoch
# Time for epoch 287 is 0.07615160942077637 sec
# 286
# end of epoch
# Time for epoch 288 is 0.08259892463684082 sec
# 287
# end of epoch
# Time for epoch 289 is 0.0685887336730957 sec
# 288
# end of epoch
# Time for epoch 290 is 0.0698847770690918 sec
# 289
# end of epoch
# Time for epoch 291 is 0.08305478096008301 sec
# 290
# end of epoch
# Time for epoch 292 is 0.087127685546875 sec
# 291
# end of epoch
# Time for epoch 293 is 0.07025265693664551 sec
# 292
# end of epoch
# Time for epoch 294 is 0.0734250545501709 sec
# 293
# end of epoch
# Time for epoch 295 is 0.08184623718261719 sec
# 294
# end of epoch
# Time for epoch 296 is 0.09221529960632324 sec
# 295
# end of epoch
# Time for epoch 297 is 0.06963992118835449 sec
# 296
# end of epoch
# Time for epoch 298 is 0.07606315612792969 sec
# 297
# end of epoch
# Time for epoch 299 is 0.0835561752319336 sec
# 298
# end of epoch
# Time for epoch 300 is 0.0801548957824707 sec
# 299
# end of epoch
# Time for epoch 301 is 0.0757145881652832 sec
# 300
# end of epoch
# Time for epoch 302 is 0.07061457633972168 sec
# 301
# end of epoch
# Time for epoch 303 is 0.08787846565246582 sec
# 302
# end of epoch
# Time for epoch 304 is 0.07101869583129883 sec
# 303
# end of epoch
# Time for epoch 305 is 0.07689547538757324 sec
# 304
# end of epoch
# Time for epoch 306 is 0.06828975677490234 sec
# 305
# end of epoch
# Time for epoch 307 is 0.0700535774230957 sec
# 306
# end of epoch
# Time for epoch 308 is 0.07093310356140137 sec
# 307
# end of epoch
# Time for epoch 309 is 0.06953668594360352 sec
# 308
# end of epoch
# Time for epoch 310 is 0.07190656661987305 sec
# 309
# end of epoch
# Time for epoch 311 is 0.07113480567932129 sec
# 310
# end of epoch
# Time for epoch 312 is 0.08304929733276367 sec
# 311
# end of epoch
# Time for epoch 313 is 0.07210111618041992 sec
# 312
# end of epoch
# Time for epoch 314 is 0.07062625885009766 sec
# 313
# end of epoch
# Time for epoch 315 is 0.0733799934387207 sec
# 314
# end of epoch
# Time for epoch 316 is 0.07144403457641602 sec
# 315
# end of epoch
# Time for epoch 317 is 0.0722203254699707 sec
# 316
# end of epoch
# Time for epoch 318 is 0.06963706016540527 sec
# 317
# end of epoch
# Time for epoch 319 is 0.07177352905273438 sec
# 318
# end of epoch
# Time for epoch 320 is 0.07878971099853516 sec
# 319
# end of epoch
# Time for epoch 321 is 0.08796215057373047 sec
# 320
# end of epoch
# Time for epoch 322 is 0.07053995132446289 sec
# 321
# end of epoch
# Time for epoch 323 is 0.07006669044494629 sec
# 322
# end of epoch
# Time for epoch 324 is 0.07294535636901855 sec
# 323
# end of epoch
# Time for epoch 325 is 0.07454895973205566 sec
# 324
# end of epoch
# Time for epoch 326 is 0.08200454711914062 sec
# 325
# end of epoch
# Time for epoch 327 is 0.07001233100891113 sec
# 326
# end of epoch
# Time for epoch 328 is 0.07244563102722168 sec
# 327
# end of epoch
# Time for epoch 329 is 0.06993818283081055 sec
# 328
# end of epoch
# Time for epoch 330 is 0.06891965866088867 sec
# 329
# end of epoch
# Time for epoch 331 is 0.07125163078308105 sec
# 330
# end of epoch
# Time for epoch 332 is 0.0952599048614502 sec
# 331
# end of epoch
# Time for epoch 333 is 0.07671189308166504 sec
# 332
# end of epoch
# Time for epoch 334 is 0.08791828155517578 sec
# 333
# end of epoch
# Time for epoch 335 is 0.06963753700256348 sec
# 334
# end of epoch
# Time for epoch 336 is 0.07448935508728027 sec
# 335
# end of epoch
# Time for epoch 337 is 0.06902861595153809 sec
# 336
# end of epoch
# Time for epoch 338 is 0.08826541900634766 sec
# 337
# end of epoch
# Time for epoch 339 is 0.07846760749816895 sec
# 338
# end of epoch
# Time for epoch 340 is 0.07654595375061035 sec
# 339
# end of epoch
# Time for epoch 341 is 0.0755472183227539 sec
# 340
# end of epoch
# Time for epoch 342 is 0.08418846130371094 sec
# 341
# end of epoch
# Time for epoch 343 is 0.07248973846435547 sec
# 342
# end of epoch
# Time for epoch 344 is 0.07102346420288086 sec
# 343
# end of epoch
# Time for epoch 345 is 0.06952285766601562 sec
# 344
# end of epoch
# Time for epoch 346 is 0.07000565528869629 sec
# 345
# end of epoch
# Time for epoch 347 is 0.07036399841308594 sec
# 346
# end of epoch
# Time for epoch 348 is 0.07147550582885742 sec
# 347
# end of epoch
# Time for epoch 349 is 0.09001016616821289 sec
# 348
# end of epoch
# Time for epoch 350 is 0.08119320869445801 sec
# 349
# end of epoch
# Time for epoch 351 is 0.08089160919189453 sec
# 350
# end of epoch
# Time for epoch 352 is 0.06881308555603027 sec
# 351
# end of epoch
# Time for epoch 353 is 0.07343292236328125 sec
# 352
# end of epoch
# Time for epoch 354 is 0.07749223709106445 sec
# 353
# end of epoch
# Time for epoch 355 is 0.07009720802307129 sec
# 354
# end of epoch
# Time for epoch 356 is 0.06995391845703125 sec
# 355
# end of epoch
# Time for epoch 357 is 0.07343244552612305 sec
# 356
# end of epoch
# Time for epoch 358 is 0.08057665824890137 sec
# 357
# end of epoch
# Time for epoch 359 is 0.06981015205383301 sec
# 358
# end of epoch
# Time for epoch 360 is 0.06971144676208496 sec
# 359
# end of epoch
# Time for epoch 361 is 0.07434654235839844 sec
# 360
# end of epoch
# Time for epoch 362 is 0.07410430908203125 sec
# 361
# end of epoch
# Time for epoch 363 is 0.07700276374816895 sec
# 362
# end of epoch
# Time for epoch 364 is 0.07111692428588867 sec
# 363
# end of epoch
# Time for epoch 365 is 0.09006881713867188 sec
# 364
# end of epoch
# Time for epoch 366 is 0.07650566101074219 sec
# 365
# end of epoch
# Time for epoch 367 is 0.07574582099914551 sec
# 366
# end of epoch
# Time for epoch 368 is 0.08037471771240234 sec
# 367
# end of epoch
# Time for epoch 369 is 0.07210302352905273 sec
# 368
# end of epoch
# Time for epoch 370 is 0.07581520080566406 sec
# 369
# end of epoch
# Time for epoch 371 is 0.07558131217956543 sec
# 370
# end of epoch
# Time for epoch 372 is 0.08147478103637695 sec
# 371
# end of epoch
# Time for epoch 373 is 0.07648968696594238 sec
# 372
# end of epoch
# Time for epoch 374 is 0.07185149192810059 sec
# 373
# end of epoch
# Time for epoch 375 is 0.06984090805053711 sec
# 374
# end of epoch
# Time for epoch 376 is 0.0825340747833252 sec
# 375
# end of epoch
# Time for epoch 377 is 0.07123208045959473 sec
# 376
# end of epoch
# Time for epoch 378 is 0.07369875907897949 sec
# 377
# end of epoch
# Time for epoch 379 is 0.0707542896270752 sec
# 378
# end of epoch
# Time for epoch 380 is 0.0790853500366211 sec
# 379
# end of epoch
# Time for epoch 381 is 0.07579803466796875 sec
# 380
# end of epoch
# Time for epoch 382 is 0.07304072380065918 sec
# 381
# end of epoch
# Time for epoch 383 is 0.07380557060241699 sec
# 382
# end of epoch
# Time for epoch 384 is 0.07066965103149414 sec
# 383
# end of epoch
# Time for epoch 385 is 0.08976197242736816 sec
# 384
# end of epoch
# Time for epoch 386 is 0.08117151260375977 sec
# 385
# end of epoch
# Time for epoch 387 is 0.07207298278808594 sec
# 386
# end of epoch
# Time for epoch 388 is 0.08911871910095215 sec
# 387
# end of epoch
# Time for epoch 389 is 0.06869316101074219 sec
# 388
# end of epoch
# Time for epoch 390 is 0.07026410102844238 sec
# 389
# end of epoch
# Time for epoch 391 is 0.06857156753540039 sec
# 390
# end of epoch
# Time for epoch 392 is 0.07898974418640137 sec
# 391
# end of epoch
# Time for epoch 393 is 0.07181882858276367 sec
# 392
# end of epoch
# Time for epoch 394 is 0.0805509090423584 sec
# 393
# end of epoch
# Time for epoch 395 is 0.06977462768554688 sec
# 394
# end of epoch
# Time for epoch 396 is 0.06923174858093262 sec
# 395
# end of epoch
# Time for epoch 397 is 0.07915520668029785 sec
# 396
# end of epoch
# Time for epoch 398 is 0.08320784568786621 sec
# 397
# end of epoch
# Time for epoch 399 is 0.08209538459777832 sec
# 398
# end of epoch
# Time for epoch 400 is 0.07886767387390137 sec
# 399
# end of epoch
# Time for epoch 401 is 0.07046914100646973 sec
# 400
# end of epoch
# Time for epoch 402 is 0.07058262825012207 sec
# 401
# end of epoch
# Time for epoch 403 is 0.06997418403625488 sec
# 402
# end of epoch
# Time for epoch 404 is 0.07255291938781738 sec
# 403
# end of epoch
# Time for epoch 405 is 0.0686500072479248 sec
# 404
# end of epoch
# Time for epoch 406 is 0.07168769836425781 sec
# 405
# end of epoch
# Time for epoch 407 is 0.0903468132019043 sec
# 406
# end of epoch
# Time for epoch 408 is 0.06942510604858398 sec
# 407
# end of epoch
# Time for epoch 409 is 0.07095742225646973 sec
# 408
# end of epoch
# Time for epoch 410 is 0.07054519653320312 sec
# 409
# end of epoch
# Time for epoch 411 is 0.07164669036865234 sec
# 410
# end of epoch
# Time for epoch 412 is 0.08270025253295898 sec
# 411
# end of epoch
# Time for epoch 413 is 0.07807731628417969 sec
# 412
# end of epoch
# Time for epoch 414 is 0.07765674591064453 sec
# 413
# end of epoch
# Time for epoch 415 is 0.06984496116638184 sec
# 414
# end of epoch
# Time for epoch 416 is 0.07483363151550293 sec
# 415
# end of epoch
# Time for epoch 417 is 0.08414411544799805 sec
# 416
# end of epoch
# Time for epoch 418 is 0.08683633804321289 sec
# 417
# end of epoch
# Time for epoch 419 is 0.07276678085327148 sec
# 418
# end of epoch
# Time for epoch 420 is 0.06934595108032227 sec
# 419
# end of epoch
# Time for epoch 421 is 0.09214448928833008 sec
# 420
# end of epoch
# Time for epoch 422 is 0.07227635383605957 sec
# 421
# end of epoch
# Time for epoch 423 is 0.0769803524017334 sec
# 422
# end of epoch
# Time for epoch 424 is 0.07309985160827637 sec
# 423
# end of epoch
# Time for epoch 425 is 0.0716094970703125 sec
# 424
# end of epoch
# Time for epoch 426 is 0.08890175819396973 sec
# 425
# end of epoch
# Time for epoch 427 is 0.07313251495361328 sec
# 426
# end of epoch
# Time for epoch 428 is 0.08256387710571289 sec
# 427
# end of epoch
# Time for epoch 429 is 0.0786583423614502 sec
# 428
# end of epoch
# Time for epoch 430 is 0.08225464820861816 sec
# 429
# end of epoch
# Time for epoch 431 is 0.07070374488830566 sec
# 430
# end of epoch
# Time for epoch 432 is 0.07370305061340332 sec
# 431
# end of epoch
# Time for epoch 433 is 0.07223057746887207 sec
# 432
# end of epoch
# Time for epoch 434 is 0.06943726539611816 sec
# 433
# end of epoch
# Time for epoch 435 is 0.07235932350158691 sec
# 434
# end of epoch
# Time for epoch 436 is 0.06916689872741699 sec
# 435
# end of epoch
# Time for epoch 437 is 0.07268118858337402 sec
# 436
# end of epoch
# Time for epoch 438 is 0.06937456130981445 sec
# 437
# end of epoch
# Time for epoch 439 is 0.07790970802307129 sec
# 438
# end of epoch
# Time for epoch 440 is 0.08166885375976562 sec
# 439
# end of epoch
# Time for epoch 441 is 0.07912755012512207 sec
# 440
# end of epoch
# Time for epoch 442 is 0.0739445686340332 sec
# 441
# end of epoch
# Time for epoch 443 is 0.07330322265625 sec
# 442
# end of epoch
# Time for epoch 444 is 0.07031512260437012 sec
# 443
# end of epoch
# Time for epoch 445 is 0.07014799118041992 sec
# 444
# end of epoch
# Time for epoch 446 is 0.07908987998962402 sec
# 445
# end of epoch
# Time for epoch 447 is 0.06952619552612305 sec
# 446
# end of epoch
# Time for epoch 448 is 0.08689308166503906 sec
# 447
# end of epoch
# Time for epoch 449 is 0.07124590873718262 sec
# 448
# end of epoch
# Time for epoch 450 is 0.07117199897766113 sec
# 449
# end of epoch
# Time for epoch 451 is 0.06934356689453125 sec
# 450
# end of epoch
# Time for epoch 452 is 0.07163405418395996 sec
# 451
# end of epoch
# Time for epoch 453 is 0.07344889640808105 sec
# 452
# end of epoch
# Time for epoch 454 is 0.07977724075317383 sec
# 453
# end of epoch
# Time for epoch 455 is 0.0714261531829834 sec
# 454
# end of epoch
# Time for epoch 456 is 0.08150386810302734 sec
# 455
# end of epoch
# Time for epoch 457 is 0.08468389511108398 sec
# 456
# end of epoch
# Time for epoch 458 is 0.07400870323181152 sec
# 457
# end of epoch
# Time for epoch 459 is 0.08177661895751953 sec
# 458
# end of epoch
# Time for epoch 460 is 0.07327508926391602 sec
# 459
# end of epoch
# Time for epoch 461 is 0.07084059715270996 sec
# 460
# end of epoch
# Time for epoch 462 is 0.06931376457214355 sec
# 461
# end of epoch
# Time for epoch 463 is 0.07136297225952148 sec
# 462
# end of epoch
# Time for epoch 464 is 0.07224702835083008 sec
# 463
# end of epoch
# Time for epoch 465 is 0.06831884384155273 sec
# 464
# end of epoch
# Time for epoch 466 is 0.07415008544921875 sec
# 465
# end of epoch
# Time for epoch 467 is 0.0699608325958252 sec
# 466
# end of epoch
# Time for epoch 468 is 0.06937193870544434 sec
# 467
# end of epoch
# Time for epoch 469 is 0.07117843627929688 sec
# 468
# end of epoch
# Time for epoch 470 is 0.07059693336486816 sec
# 469
# end of epoch
# Time for epoch 471 is 0.07074809074401855 sec
# 470
# end of epoch
# Time for epoch 472 is 0.07022929191589355 sec
# 471
# end of epoch
# Time for epoch 473 is 0.07095456123352051 sec
# 472
# end of epoch
# Time for epoch 474 is 0.07220339775085449 sec
# 473
# end of epoch
# Time for epoch 475 is 0.07633638381958008 sec
# 474
# end of epoch
# Time for epoch 476 is 0.08856415748596191 sec
# 475
# end of epoch
# Time for epoch 477 is 0.07328295707702637 sec
# 476
# end of epoch
# Time for epoch 478 is 0.07877731323242188 sec
# 477
# end of epoch
# Time for epoch 479 is 0.07323360443115234 sec
# 478
# end of epoch
# Time for epoch 480 is 0.07722806930541992 sec
# 479
# end of epoch
# Time for epoch 481 is 0.07159090042114258 sec
# 480
# end of epoch
# Time for epoch 482 is 0.06860828399658203 sec
# 481
# end of epoch
# Time for epoch 483 is 0.07211899757385254 sec
# 482
# end of epoch
# Time for epoch 484 is 0.07161593437194824 sec
# 483
# end of epoch
# Time for epoch 485 is 0.07472681999206543 sec
# 484
# end of epoch
# Time for epoch 486 is 0.07456588745117188 sec
# 485
# end of epoch
# Time for epoch 487 is 0.0747673511505127 sec
# 486
# end of epoch
# Time for epoch 488 is 0.08122777938842773 sec
# 487
# end of epoch
# Time for epoch 489 is 0.07092809677124023 sec
# 488
# end of epoch
# Time for epoch 490 is 0.07097935676574707 sec
# 489
# end of epoch
# Time for epoch 491 is 0.06910061836242676 sec
# 490
# end of epoch
# Time for epoch 492 is 0.07085895538330078 sec
# 491
# end of epoch
# Time for epoch 493 is 0.06952714920043945 sec
# 492
# end of epoch
# Time for epoch 494 is 0.07820749282836914 sec
# 493
# end of epoch
# Time for epoch 495 is 0.08220148086547852 sec
# 494
# end of epoch
# Time for epoch 496 is 0.07052326202392578 sec
# 495
# end of epoch
# Time for epoch 497 is 0.08671140670776367 sec
# 496
# end of epoch
# Time for epoch 498 is 0.07466483116149902 sec
# 497
# end of epoch
# Time for epoch 499 is 0.07159924507141113 sec
# 498
# end of epoch
# Time for epoch 500 is 0.07533383369445801 sec
# 499
# end of epoch
# Time for epoch 501 is 0.07289600372314453 sec
# 500
# end of epoch
# Time for epoch 502 is 0.07321524620056152 sec
# 501
# end of epoch
# Time for epoch 503 is 0.07781314849853516 sec
# 502
# end of epoch
# Time for epoch 504 is 0.06958556175231934 sec
# 503
# end of epoch
# Time for epoch 505 is 0.07191729545593262 sec
# 504
# end of epoch
# Time for epoch 506 is 0.07503294944763184 sec
# 505
# end of epoch
# Time for epoch 507 is 0.07100796699523926 sec
# 506
# end of epoch
# Time for epoch 508 is 0.06981158256530762 sec
# 507
# end of epoch
# Time for epoch 509 is 0.08464956283569336 sec
# 508
# end of epoch
# Time for epoch 510 is 0.08636879920959473 sec
# 509
# end of epoch
# Time for epoch 511 is 0.07231664657592773 sec
# 510
# end of epoch
# Time for epoch 512 is 0.07319498062133789 sec
# 511
# end of epoch
# Time for epoch 513 is 0.09567546844482422 sec
# 512
# end of epoch
# Time for epoch 514 is 0.07330083847045898 sec
# 513
# end of epoch
# Time for epoch 515 is 0.08001565933227539 sec
# 514
# end of epoch
# Time for epoch 516 is 0.07262682914733887 sec
# 515
# end of epoch
# Time for epoch 517 is 0.07681846618652344 sec
# 516
# end of epoch
# Time for epoch 518 is 0.09399294853210449 sec
# 517
# end of epoch
# Time for epoch 519 is 0.07464146614074707 sec
# 518
# end of epoch
# Time for epoch 520 is 0.0777895450592041 sec
# 519
# end of epoch
# Time for epoch 521 is 0.08933448791503906 sec
# 520
# end of epoch
# Time for epoch 522 is 0.07479000091552734 sec
# 521
# end of epoch
# Time for epoch 523 is 0.06989383697509766 sec
# 522
# end of epoch
# Time for epoch 524 is 0.07186555862426758 sec
# 523
# end of epoch
# Time for epoch 525 is 0.07522892951965332 sec
# 524
# end of epoch
# Time for epoch 526 is 0.07398104667663574 sec
# 525
# end of epoch
# Time for epoch 527 is 0.0715947151184082 sec
# 526
# end of epoch
# Time for epoch 528 is 0.07125377655029297 sec
# 527
# end of epoch
# Time for epoch 529 is 0.07643747329711914 sec
# 528
# end of epoch
# Time for epoch 530 is 0.0748748779296875 sec
# 529
# end of epoch
# Time for epoch 531 is 0.07962822914123535 sec
# 530
# end of epoch
# Time for epoch 532 is 0.07963681221008301 sec
# 531
# end of epoch
# Time for epoch 533 is 0.07503414154052734 sec
# 532
# end of epoch
# Time for epoch 534 is 0.0864722728729248 sec
# 533
# end of epoch
# Time for epoch 535 is 0.07479667663574219 sec
# 534
# end of epoch
# Time for epoch 536 is 0.07215642929077148 sec
# 535
# end of epoch
# Time for epoch 537 is 0.07709836959838867 sec
# 536
# end of epoch
# Time for epoch 538 is 0.0728158950805664 sec
# 537
# end of epoch
# Time for epoch 539 is 0.08839106559753418 sec
# 538
# end of epoch
# Time for epoch 540 is 0.0776817798614502 sec
# 539
# end of epoch
# Time for epoch 541 is 0.07348871231079102 sec
# 540
# end of epoch
# Time for epoch 542 is 0.07176017761230469 sec
# 541
# end of epoch
# Time for epoch 543 is 0.0726480484008789 sec
# 542
# end of epoch
# Time for epoch 544 is 0.07315754890441895 sec
# 543
# end of epoch
# Time for epoch 545 is 0.08624696731567383 sec
# 544
# end of epoch
# Time for epoch 546 is 0.07485318183898926 sec
# 545
# end of epoch
# Time for epoch 547 is 0.07517027854919434 sec
# 546
# end of epoch
# Time for epoch 548 is 0.07150459289550781 sec
# 547
# end of epoch
# Time for epoch 549 is 0.08678507804870605 sec
# 548
# end of epoch
# Time for epoch 550 is 0.0712118148803711 sec
# 549
# end of epoch
# Time for epoch 551 is 0.07633686065673828 sec
# 550
# end of epoch
# Time for epoch 552 is 0.07612824440002441 sec
# 551
# end of epoch
# Time for epoch 553 is 0.07260012626647949 sec
# 552
# end of epoch
# Time for epoch 554 is 0.07547450065612793 sec
# 553
# end of epoch
# Time for epoch 555 is 0.07353544235229492 sec
# 554
# end of epoch
# Time for epoch 556 is 0.08182978630065918 sec
# 555
# end of epoch
# Time for epoch 557 is 0.07363033294677734 sec
# 556
# end of epoch
# Time for epoch 558 is 0.07970476150512695 sec
# 557
# end of epoch
# Time for epoch 559 is 0.07536077499389648 sec
# 558
# end of epoch
# Time for epoch 560 is 0.08932614326477051 sec
# 559
# end of epoch
# Time for epoch 561 is 0.08606433868408203 sec
# 560
# end of epoch
# Time for epoch 562 is 0.07328057289123535 sec
# 561
# end of epoch
# Time for epoch 563 is 0.08094024658203125 sec
# 562
# end of epoch
# Time for epoch 564 is 0.07254457473754883 sec
# 563
# end of epoch
# Time for epoch 565 is 0.09245538711547852 sec
# 564
# end of epoch
# Time for epoch 566 is 0.07227921485900879 sec
# 565
# end of epoch
# Time for epoch 567 is 0.08367109298706055 sec
# 566
# end of epoch
# Time for epoch 568 is 0.07328557968139648 sec
# 567
# end of epoch
# Time for epoch 569 is 0.07797956466674805 sec
# 568
# end of epoch
# Time for epoch 570 is 0.08600139617919922 sec
# 569
# end of epoch
# Time for epoch 571 is 0.0735025405883789 sec
# 570
# end of epoch
# Time for epoch 572 is 0.0821225643157959 sec
# 571
# end of epoch
# Time for epoch 573 is 0.07448625564575195 sec
# 572
# end of epoch
# Time for epoch 574 is 0.08164000511169434 sec
# 573
# end of epoch
# Time for epoch 575 is 0.0910491943359375 sec
# 574
# end of epoch
# Time for epoch 576 is 0.07324910163879395 sec
# 575
# end of epoch
# Time for epoch 577 is 0.07358312606811523 sec
# 576
# end of epoch
# Time for epoch 578 is 0.07327532768249512 sec
# 577
# end of epoch
# Time for epoch 579 is 0.08680272102355957 sec
# 578
# end of epoch
# Time for epoch 580 is 0.08019399642944336 sec
# 579
# end of epoch
# Time for epoch 581 is 0.08723711967468262 sec
# 580
# end of epoch
# Time for epoch 582 is 0.07444572448730469 sec
# 581
# end of epoch
# Time for epoch 583 is 0.0828399658203125 sec
# 582
# end of epoch
# Time for epoch 584 is 0.07394003868103027 sec
# 583
# end of epoch
# Time for epoch 585 is 0.08903384208679199 sec
# 584
# end of epoch
# Time for epoch 586 is 0.09758758544921875 sec
# 585
# end of epoch
# Time for epoch 587 is 0.08420586585998535 sec
# 586
# end of epoch
# Time for epoch 588 is 0.08744668960571289 sec
# 587
# end of epoch
# Time for epoch 589 is 0.07079648971557617 sec
# 588
# end of epoch
# Time for epoch 590 is 0.08764004707336426 sec
# 589
# end of epoch
# Time for epoch 591 is 0.0712890625 sec
# 590
# end of epoch
# Time for epoch 592 is 0.07459354400634766 sec
# 591
# end of epoch
# Time for epoch 593 is 0.07586073875427246 sec
# 592
# end of epoch
# Time for epoch 594 is 0.07786130905151367 sec
# 593
# end of epoch
# Time for epoch 595 is 0.0741419792175293 sec
# 594
# end of epoch
# Time for epoch 596 is 0.07500123977661133 sec
# 595
# end of epoch
# Time for epoch 597 is 0.08455395698547363 sec
# 596
# end of epoch
# Time for epoch 598 is 0.07215309143066406 sec
# 597
# end of epoch
# Time for epoch 599 is 0.08186531066894531 sec
# 598
# end of epoch
# Time for epoch 600 is 0.07916426658630371 sec
# 599
# end of epoch
# Time for epoch 601 is 0.08243083953857422 sec
# 600
# end of epoch
# Time for epoch 602 is 0.07923102378845215 sec
# 601
# end of epoch
# Time for epoch 603 is 0.07696199417114258 sec
# 602
# end of epoch
# Time for epoch 604 is 0.07494449615478516 sec
# 603
# end of epoch
# Time for epoch 605 is 0.07190513610839844 sec
# 604
# end of epoch
# Time for epoch 606 is 0.07373404502868652 sec
# 605
# end of epoch
# Time for epoch 607 is 0.0830845832824707 sec
# 606
# end of epoch
# Time for epoch 608 is 0.08120346069335938 sec
# 607
# end of epoch
# Time for epoch 609 is 0.07917976379394531 sec
# 608
# end of epoch
# Time for epoch 610 is 0.07672786712646484 sec
# 609
# end of epoch
# Time for epoch 611 is 0.08154535293579102 sec
# 610
# end of epoch
# Time for epoch 612 is 0.0879065990447998 sec
# 611
# end of epoch
# Time for epoch 613 is 0.07655191421508789 sec
# 612
# end of epoch
# Time for epoch 614 is 0.09173130989074707 sec
# 613
# end of epoch
# Time for epoch 615 is 0.07657003402709961 sec
# 614
# end of epoch
# Time for epoch 616 is 0.08285975456237793 sec
# 615
# end of epoch
# Time for epoch 617 is 0.0751497745513916 sec
# 616
# end of epoch
# Time for epoch 618 is 0.07647347450256348 sec
# 617
# end of epoch
# Time for epoch 619 is 0.07377815246582031 sec
# 618
# end of epoch
# Time for epoch 620 is 0.09506416320800781 sec
# 619
# end of epoch
# Time for epoch 621 is 0.07108569145202637 sec
# 620
# end of epoch
# Time for epoch 622 is 0.09411835670471191 sec
# 621
# end of epoch
# Time for epoch 623 is 0.07235002517700195 sec
# 622
# end of epoch
# Time for epoch 624 is 0.07551002502441406 sec
# 623
# end of epoch
# Time for epoch 625 is 0.07686042785644531 sec
# 624
# end of epoch
# Time for epoch 626 is 0.07559919357299805 sec
# 625
# end of epoch
# Time for epoch 627 is 0.08556556701660156 sec
# 626
# end of epoch
# Time for epoch 628 is 0.0745854377746582 sec
# 627
# end of epoch
# Time for epoch 629 is 0.0737605094909668 sec
# 628
# end of epoch
# Time for epoch 630 is 0.07403039932250977 sec
# 629
# end of epoch
# Time for epoch 631 is 0.08419108390808105 sec
# 630
# end of epoch
# Time for epoch 632 is 0.07741236686706543 sec
# 631
# end of epoch
# Time for epoch 633 is 0.08751082420349121 sec
# 632
# end of epoch
# Time for epoch 634 is 0.08415818214416504 sec
# 633
# end of epoch
# Time for epoch 635 is 0.07732391357421875 sec
# 634
# end of epoch
# Time for epoch 636 is 0.07708382606506348 sec
# 635
# end of epoch
# Time for epoch 637 is 0.08331513404846191 sec
# 636
# end of epoch
# Time for epoch 638 is 0.07300996780395508 sec
# 637
# end of epoch
# Time for epoch 639 is 0.0723884105682373 sec
# 638
# end of epoch
# Time for epoch 640 is 0.08193492889404297 sec
# 639
# end of epoch
# Time for epoch 641 is 0.07335329055786133 sec
# 640
# end of epoch
# Time for epoch 642 is 0.08603096008300781 sec
# 641
# end of epoch
# Time for epoch 643 is 0.07379937171936035 sec
# 642
# end of epoch
# Time for epoch 644 is 0.0744180679321289 sec
# 643
# end of epoch
# Time for epoch 645 is 0.07438063621520996 sec
# 644
# end of epoch
# Time for epoch 646 is 0.07139229774475098 sec
# 645
# end of epoch
# Time for epoch 647 is 0.0723714828491211 sec
# 646
# end of epoch
# Time for epoch 648 is 0.0768275260925293 sec
# 647
# end of epoch
# Time for epoch 649 is 0.07636570930480957 sec
# 648
# end of epoch
# Time for epoch 650 is 0.07441329956054688 sec
# 649
# end of epoch
# Time for epoch 651 is 0.09035325050354004 sec
# 650
# end of epoch
# Time for epoch 652 is 0.07238125801086426 sec
# 651
# end of epoch
# Time for epoch 653 is 0.07637977600097656 sec
# 652
# end of epoch
# Time for epoch 654 is 0.07471656799316406 sec
# 653
# end of epoch
# Time for epoch 655 is 0.07291841506958008 sec
# 654
# end of epoch
# Time for epoch 656 is 0.07543468475341797 sec
# 655
# end of epoch
# Time for epoch 657 is 0.08146905899047852 sec
# 656
# end of epoch
# Time for epoch 658 is 0.0757591724395752 sec
# 657
# end of epoch
# Time for epoch 659 is 0.0836338996887207 sec
# 658
# end of epoch
# Time for epoch 660 is 0.07761693000793457 sec
# 659
# end of epoch
# Time for epoch 661 is 0.07157492637634277 sec
# 660
# end of epoch
# Time for epoch 662 is 0.07519412040710449 sec
# 661
# end of epoch
# Time for epoch 663 is 0.07489132881164551 sec
# 662
# end of epoch
# Time for epoch 664 is 0.07497763633728027 sec
# 663
# end of epoch
# Time for epoch 665 is 0.0804743766784668 sec
# 664
# end of epoch
# Time for epoch 666 is 0.07632851600646973 sec
# 665
# end of epoch
# Time for epoch 667 is 0.07441902160644531 sec
# 666
# end of epoch
# Time for epoch 668 is 0.07348513603210449 sec
# 667
# end of epoch
# Time for epoch 669 is 0.08557772636413574 sec
# 668
# end of epoch
# Time for epoch 670 is 0.08083796501159668 sec
# 669
# end of epoch
# Time for epoch 671 is 0.07305049896240234 sec
# 670
# end of epoch
# Time for epoch 672 is 0.08067750930786133 sec
# 671
# end of epoch
# Time for epoch 673 is 0.0783994197845459 sec
# 672
# end of epoch
# Time for epoch 674 is 0.08282351493835449 sec
# 673
# end of epoch
# Time for epoch 675 is 0.07205462455749512 sec
# 674
# end of epoch
# Time for epoch 676 is 0.07502388954162598 sec
# 675
# end of epoch
# Time for epoch 677 is 0.07315802574157715 sec
# 676
# end of epoch
# Time for epoch 678 is 0.0750739574432373 sec
# 677
# end of epoch
# Time for epoch 679 is 0.07381987571716309 sec
# 678
# end of epoch
# Time for epoch 680 is 0.07474589347839355 sec
# 679
# end of epoch
# Time for epoch 681 is 0.07413196563720703 sec
# 680
# end of epoch
# Time for epoch 682 is 0.07631230354309082 sec
# 681
# end of epoch
# Time for epoch 683 is 0.0794668197631836 sec
# 682
# end of epoch
# Time for epoch 684 is 0.07261395454406738 sec
# 683
# end of epoch
# Time for epoch 685 is 0.07725930213928223 sec
# 684
# end of epoch
# Time for epoch 686 is 0.0732583999633789 sec
# 685
# end of epoch
# Time for epoch 687 is 0.07567334175109863 sec
# 686
# end of epoch
# Time for epoch 688 is 0.09426403045654297 sec
# 687
# end of epoch
# Time for epoch 689 is 0.0837094783782959 sec
# 688
# end of epoch
# Time for epoch 690 is 0.07771492004394531 sec
# 689
# end of epoch
# Time for epoch 691 is 0.08761477470397949 sec
# 690
# end of epoch
# Time for epoch 692 is 0.08712482452392578 sec
# 691
# end of epoch
# Time for epoch 693 is 0.07427048683166504 sec
# 692
# end of epoch
# Time for epoch 694 is 0.0776526927947998 sec
# 693
# end of epoch
# Time for epoch 695 is 0.0719459056854248 sec
# 694
# end of epoch
# Time for epoch 696 is 0.07339906692504883 sec
# 695
# end of epoch
# Time for epoch 697 is 0.08501720428466797 sec
# 696
# end of epoch
# Time for epoch 698 is 0.07561278343200684 sec
# 697
# end of epoch
# Time for epoch 699 is 0.08938765525817871 sec
# 698
# end of epoch
# Time for epoch 700 is 0.07269859313964844 sec
# 699
# end of epoch
# Time for epoch 701 is 0.09187054634094238 sec
# 700
# end of epoch
# Time for epoch 702 is 0.07731986045837402 sec
# 701
# end of epoch
# Time for epoch 703 is 0.07674026489257812 sec
# 702
# end of epoch
# Time for epoch 704 is 0.07403397560119629 sec
# 703
# end of epoch
# Time for epoch 705 is 0.09688401222229004 sec
# 704
# end of epoch
# Time for epoch 706 is 0.08168292045593262 sec
# 705
# end of epoch
# Time for epoch 707 is 0.0939948558807373 sec
# 706
# end of epoch
# Time for epoch 708 is 0.08217906951904297 sec
# 707
# end of epoch
# Time for epoch 709 is 0.07941818237304688 sec
# 708
# end of epoch
# Time for epoch 710 is 0.08618330955505371 sec
# 709
# end of epoch
# Time for epoch 711 is 0.08247160911560059 sec
# 710
# end of epoch
# Time for epoch 712 is 0.07558131217956543 sec
# 711
# end of epoch
# Time for epoch 713 is 0.07410526275634766 sec
# 712
# end of epoch
# Time for epoch 714 is 0.07504749298095703 sec
# 713
# end of epoch
# Time for epoch 715 is 0.07944488525390625 sec
# 714
# end of epoch
# Time for epoch 716 is 0.07207965850830078 sec
# 715
# end of epoch
# Time for epoch 717 is 0.07583069801330566 sec
# 716
# end of epoch
# Time for epoch 718 is 0.07692551612854004 sec
# 717
# end of epoch
# Time for epoch 719 is 0.07293200492858887 sec
# 718
# end of epoch
# Time for epoch 720 is 0.07500505447387695 sec
# 719
# end of epoch
# Time for epoch 721 is 0.08711552619934082 sec
# 720
# end of epoch
# Time for epoch 722 is 0.0792243480682373 sec
# 721
# end of epoch
# Time for epoch 723 is 0.08051753044128418 sec
# 722
# end of epoch
# Time for epoch 724 is 0.07828736305236816 sec
# 723
# end of epoch
# Time for epoch 725 is 0.07061290740966797 sec
# 724
# end of epoch
# Time for epoch 726 is 0.0752260684967041 sec
# 725
# end of epoch
# Time for epoch 727 is 0.07156634330749512 sec
# 726
# end of epoch
# Time for epoch 728 is 0.07310032844543457 sec
# 727
# end of epoch
# Time for epoch 729 is 0.08089017868041992 sec
# 728
# end of epoch
# Time for epoch 730 is 0.07362079620361328 sec
# 729
# end of epoch
# Time for epoch 731 is 0.0769953727722168 sec
# 730
# end of epoch
# Time for epoch 732 is 0.09153389930725098 sec
# 731
# end of epoch
# Time for epoch 733 is 0.08379006385803223 sec
# 732
# end of epoch
# Time for epoch 734 is 0.07250761985778809 sec
# 733
# end of epoch
# Time for epoch 735 is 0.0814974308013916 sec
# 734
# end of epoch
# Time for epoch 736 is 0.07921385765075684 sec
# 735
# end of epoch
# Time for epoch 737 is 0.07329034805297852 sec
# 736
# end of epoch
# Time for epoch 738 is 0.07742953300476074 sec
# 737
# end of epoch
# Time for epoch 739 is 0.07430887222290039 sec
# 738
# end of epoch
# Time for epoch 740 is 0.08780169486999512 sec
# 739
# end of epoch
# Time for epoch 741 is 0.07445096969604492 sec
# 740
# end of epoch
# Time for epoch 742 is 0.08696174621582031 sec
# 741
# end of epoch
# Time for epoch 743 is 0.07236242294311523 sec
# 742
# end of epoch
# Time for epoch 744 is 0.07533407211303711 sec
# 743
# end of epoch
# Time for epoch 745 is 0.07491564750671387 sec
# 744
# end of epoch
# Time for epoch 746 is 0.07563161849975586 sec
# 745
# end of epoch
# Time for epoch 747 is 0.07355570793151855 sec
# 746
# end of epoch
# Time for epoch 748 is 0.07483744621276855 sec
# 747
# end of epoch
# Time for epoch 749 is 0.09365606307983398 sec
# 748
# end of epoch
# Time for epoch 750 is 0.0732870101928711 sec
# 749
# end of epoch
# Time for epoch 751 is 0.08699369430541992 sec
# 750
# end of epoch
# Time for epoch 752 is 0.08786797523498535 sec
# 751
# end of epoch
# Time for epoch 753 is 0.07666850090026855 sec
# 752
# end of epoch
# Time for epoch 754 is 0.07496380805969238 sec
# 753
# end of epoch
# Time for epoch 755 is 0.0716710090637207 sec
# 754
# end of epoch
# Time for epoch 756 is 0.09683465957641602 sec
# 755
# end of epoch
# Time for epoch 757 is 0.07294702529907227 sec
# 756
# end of epoch
# Time for epoch 758 is 0.07096552848815918 sec
# 757
# end of epoch
# Time for epoch 759 is 0.08376407623291016 sec
# 758
# end of epoch
# Time for epoch 760 is 0.07893133163452148 sec
# 759
# end of epoch
# Time for epoch 761 is 0.08675813674926758 sec
# 760
# end of epoch
# Time for epoch 762 is 0.0806572437286377 sec
# 761
# end of epoch
# Time for epoch 763 is 0.0956575870513916 sec
# 762
# end of epoch
# Time for epoch 764 is 0.08668398857116699 sec
# 763
# end of epoch
# Time for epoch 765 is 0.07549500465393066 sec
# 764
# end of epoch
# Time for epoch 766 is 0.07766199111938477 sec
# 765
# end of epoch
# Time for epoch 767 is 0.07258892059326172 sec
# 766
# end of epoch
# Time for epoch 768 is 0.0975034236907959 sec
# 767
# end of epoch
# Time for epoch 769 is 0.08201360702514648 sec
# 768
# end of epoch
# Time for epoch 770 is 0.08250999450683594 sec
# 769
# end of epoch
# Time for epoch 771 is 0.07574319839477539 sec
# 770
# end of epoch
# Time for epoch 772 is 0.07011842727661133 sec
# 771
# end of epoch
# Time for epoch 773 is 0.0774073600769043 sec
# 772
# end of epoch
# Time for epoch 774 is 0.07667779922485352 sec
# 773
# end of epoch
# Time for epoch 775 is 0.0783689022064209 sec
# 774
# end of epoch
# Time for epoch 776 is 0.07669830322265625 sec
# 775
# end of epoch
# Time for epoch 777 is 0.07721376419067383 sec
# 776
# end of epoch
# Time for epoch 778 is 0.07291865348815918 sec
# 777
# end of epoch
# Time for epoch 779 is 0.07831168174743652 sec
# 778
# end of epoch
# Time for epoch 780 is 0.0867455005645752 sec
# 779
# end of epoch
# Time for epoch 781 is 0.0752859115600586 sec
# 780
# end of epoch
# Time for epoch 782 is 0.09392285346984863 sec
# 781
# end of epoch
# Time for epoch 783 is 0.0732724666595459 sec
# 782
# end of epoch
# Time for epoch 784 is 0.08297228813171387 sec
# 783
# end of epoch
# Time for epoch 785 is 0.07273006439208984 sec
# 784
# end of epoch
# Time for epoch 786 is 0.0936880111694336 sec
# 785
# end of epoch
# Time for epoch 787 is 0.07222247123718262 sec
# 786
# end of epoch
# Time for epoch 788 is 0.08323335647583008 sec
# 787
# end of epoch
# Time for epoch 789 is 0.07107067108154297 sec
# 788
# end of epoch
# Time for epoch 790 is 0.07380151748657227 sec
# 789
# end of epoch
# Time for epoch 791 is 0.07333803176879883 sec
# 790
# end of epoch
# Time for epoch 792 is 0.07210111618041992 sec
# 791
# end of epoch
# Time for epoch 793 is 0.0736534595489502 sec
# 792
# end of epoch
# Time for epoch 794 is 0.07274365425109863 sec
# 793
# end of epoch
# Time for epoch 795 is 0.08426666259765625 sec
# 794
# end of epoch
# Time for epoch 796 is 0.0736689567565918 sec
# 795
# end of epoch
# Time for epoch 797 is 0.07807230949401855 sec
# 796
# end of epoch
# Time for epoch 798 is 0.07516098022460938 sec
# 797
# end of epoch
# Time for epoch 799 is 0.07753276824951172 sec
# 798
# end of epoch
# Time for epoch 800 is 0.08259272575378418 sec
# 799
# end of epoch
# Time for epoch 801 is 0.08840608596801758 sec
# 800
# end of epoch
# Time for epoch 802 is 0.07768702507019043 sec
# 801
# end of epoch
# Time for epoch 803 is 0.07222175598144531 sec
# 802
# end of epoch
# Time for epoch 804 is 0.07351160049438477 sec
# 803
# end of epoch
# Time for epoch 805 is 0.07318854331970215 sec
# 804
# end of epoch
# Time for epoch 806 is 0.07315635681152344 sec
# 805
# end of epoch
# Time for epoch 807 is 0.07632136344909668 sec
# 806
# end of epoch
# Time for epoch 808 is 0.07237982749938965 sec
# 807
# end of epoch
# Time for epoch 809 is 0.07747292518615723 sec
# 808
# end of epoch
# Time for epoch 810 is 0.07523679733276367 sec
# 809
# end of epoch
# Time for epoch 811 is 0.09207582473754883 sec
# 810
# end of epoch
# Time for epoch 812 is 0.08926272392272949 sec
# 811
# end of epoch
# Time for epoch 813 is 0.07606244087219238 sec
# 812
# end of epoch
# Time for epoch 814 is 0.0886690616607666 sec
# 813
# end of epoch
# Time for epoch 815 is 0.07500553131103516 sec
# 814
# end of epoch
# Time for epoch 816 is 0.07585549354553223 sec
# 815
# end of epoch
# Time for epoch 817 is 0.07762765884399414 sec
# 816
# end of epoch
# Time for epoch 818 is 0.09514403343200684 sec
# 817
# end of epoch
# Time for epoch 819 is 0.0730290412902832 sec
# 818
# end of epoch
# Time for epoch 820 is 0.08913135528564453 sec
# 819
# end of epoch
# Time for epoch 821 is 0.07199311256408691 sec
# 820
# end of epoch
# Time for epoch 822 is 0.0994422435760498 sec
# 821
# end of epoch
# Time for epoch 823 is 0.075042724609375 sec
# 822
# end of epoch
# Time for epoch 824 is 0.07310938835144043 sec
# 823
# end of epoch
# Time for epoch 825 is 0.07441186904907227 sec
# 824
# end of epoch
# Time for epoch 826 is 0.09237861633300781 sec
# 825
# end of epoch
# Time for epoch 827 is 0.08129429817199707 sec
# 826
# end of epoch
# Time for epoch 828 is 0.07740950584411621 sec
# 827
# end of epoch
# Time for epoch 829 is 0.07233929634094238 sec
# 828
# end of epoch
# Time for epoch 830 is 0.08987736701965332 sec
# 829
# end of epoch
# Time for epoch 831 is 0.0822458267211914 sec
# 830
# end of epoch
# Time for epoch 832 is 0.0749979019165039 sec
# 831
# end of epoch
# Time for epoch 833 is 0.07422375679016113 sec
# 832
# end of epoch
# Time for epoch 834 is 0.07449722290039062 sec
# 833
# end of epoch
# Time for epoch 835 is 0.09178543090820312 sec
# 834
# end of epoch
# Time for epoch 836 is 0.07573795318603516 sec
# 835
# end of epoch
# Time for epoch 837 is 0.09343385696411133 sec
# 836
# end of epoch
# Time for epoch 838 is 0.07224726676940918 sec
# 837
# end of epoch
# Time for epoch 839 is 0.08656525611877441 sec
# 838
# end of epoch
# Time for epoch 840 is 0.07096314430236816 sec
# 839
# end of epoch
# Time for epoch 841 is 0.07960033416748047 sec
# 840
# end of epoch
# Time for epoch 842 is 0.07217025756835938 sec
# 841
# end of epoch
# Time for epoch 843 is 0.07263326644897461 sec
# 842
# end of epoch
# Time for epoch 844 is 0.07908129692077637 sec
# 843
# end of epoch
# Time for epoch 845 is 0.0989375114440918 sec
# 844
# end of epoch
# Time for epoch 846 is 0.08920168876647949 sec
# 845
# end of epoch
# Time for epoch 847 is 0.08756065368652344 sec
# 846
# end of epoch
# Time for epoch 848 is 0.07441139221191406 sec
# 847
# end of epoch
# Time for epoch 849 is 0.07670807838439941 sec
# 848
# end of epoch
# Time for epoch 850 is 0.09209918975830078 sec
# 849
# end of epoch
# Time for epoch 851 is 0.08167767524719238 sec
# 850
# end of epoch
# Time for epoch 852 is 0.08319997787475586 sec
# 851
# end of epoch
# Time for epoch 853 is 0.08027148246765137 sec
# 852
# end of epoch
# Time for epoch 854 is 0.08049607276916504 sec
# 853
# end of epoch
# Time for epoch 855 is 0.07792472839355469 sec
# 854
# end of epoch
# Time for epoch 856 is 0.08067607879638672 sec
# 855
# end of epoch
# Time for epoch 857 is 0.07760262489318848 sec
# 856
# end of epoch
# Time for epoch 858 is 0.08078551292419434 sec
# 857
# end of epoch
# Time for epoch 859 is 0.10046601295471191 sec
# 858
# end of epoch
# Time for epoch 860 is 0.0755465030670166 sec
# 859
# end of epoch
# Time for epoch 861 is 0.07519006729125977 sec
# 860
# end of epoch
# Time for epoch 862 is 0.09124159812927246 sec
# 861
# end of epoch
# Time for epoch 863 is 0.08893585205078125 sec
# 862
# end of epoch
# Time for epoch 864 is 0.08762168884277344 sec
# 863
# end of epoch
# Time for epoch 865 is 0.07542657852172852 sec
# 864
# end of epoch
# Time for epoch 866 is 0.074188232421875 sec
# 865
# end of epoch
# Time for epoch 867 is 0.08947157859802246 sec
# 866
# end of epoch
# Time for epoch 868 is 0.07451462745666504 sec
# 867
# end of epoch
# Time for epoch 869 is 0.10610079765319824 sec
# 868
# end of epoch
# Time for epoch 870 is 0.07610726356506348 sec
# 869
# end of epoch
# Time for epoch 871 is 0.08249640464782715 sec
# 870
# end of epoch
# Time for epoch 872 is 0.0861806869506836 sec
# 871
# end of epoch
# Time for epoch 873 is 0.08896851539611816 sec
# 872
# end of epoch
# Time for epoch 874 is 0.07810401916503906 sec
# 873
# end of epoch
# Time for epoch 875 is 0.07427740097045898 sec
# 874
# end of epoch
# Time for epoch 876 is 0.07462167739868164 sec
# 875
# end of epoch
# Time for epoch 877 is 0.07387518882751465 sec
# 876
# end of epoch
# Time for epoch 878 is 0.09084630012512207 sec
# 877
# end of epoch
# Time for epoch 879 is 0.07298421859741211 sec
# 878
# end of epoch
# Time for epoch 880 is 0.07351970672607422 sec
# 879
# end of epoch
# Time for epoch 881 is 0.07106733322143555 sec
# 880
# end of epoch
# Time for epoch 882 is 0.07281804084777832 sec
# 881
# end of epoch
# Time for epoch 883 is 0.07442092895507812 sec
# 882
# end of epoch
# Time for epoch 884 is 0.07308363914489746 sec
# 883
# end of epoch
# Time for epoch 885 is 0.0755467414855957 sec
# 884
# end of epoch
# Time for epoch 886 is 0.07261991500854492 sec
# 885
# end of epoch
# Time for epoch 887 is 0.07125616073608398 sec
# 886
# end of epoch
# Time for epoch 888 is 0.07514572143554688 sec
# 887
# end of epoch
# Time for epoch 889 is 0.07471179962158203 sec
# 888
# end of epoch
# Time for epoch 890 is 0.07796359062194824 sec
# 889
# end of epoch
# Time for epoch 891 is 0.07383871078491211 sec
# 890
# end of epoch
# Time for epoch 892 is 0.07126092910766602 sec
# 891
# end of epoch
# Time for epoch 893 is 0.07433533668518066 sec
# 892
# end of epoch
# Time for epoch 894 is 0.0772092342376709 sec
# 893
# end of epoch
# Time for epoch 895 is 0.07809925079345703 sec
# 894
# end of epoch
# Time for epoch 896 is 0.08606624603271484 sec
# 895
# end of epoch
# Time for epoch 897 is 0.0776522159576416 sec
# 896
# end of epoch
# Time for epoch 898 is 0.07378768920898438 sec
# 897
# end of epoch
# Time for epoch 899 is 0.07658123970031738 sec
# 898
# end of epoch
# Time for epoch 900 is 0.07818150520324707 sec
# 899
# end of epoch
# Time for epoch 901 is 0.07491111755371094 sec
# 900
# end of epoch
# Time for epoch 902 is 0.0729222297668457 sec
# 901
# end of epoch
# Time for epoch 903 is 0.08830475807189941 sec
# 902
# end of epoch
# Time for epoch 904 is 0.07307195663452148 sec
# 903
# end of epoch
# Time for epoch 905 is 0.07518815994262695 sec
# 904
# end of epoch
# Time for epoch 906 is 0.07416439056396484 sec
# 905
# end of epoch
# Time for epoch 907 is 0.0791323184967041 sec
# 906
# end of epoch
# Time for epoch 908 is 0.07713127136230469 sec
# 907
# end of epoch
# Time for epoch 909 is 0.08121132850646973 sec
# 908
# end of epoch
# Time for epoch 910 is 0.07927727699279785 sec
# 909
# end of epoch
# Time for epoch 911 is 0.07267093658447266 sec
# 910
# end of epoch
# Time for epoch 912 is 0.07670307159423828 sec
# 911
# end of epoch
# Time for epoch 913 is 0.08533883094787598 sec
# 912
# end of epoch
# Time for epoch 914 is 0.09272074699401855 sec
# 913
# end of epoch
# Time for epoch 915 is 0.07762384414672852 sec
# 914
# end of epoch
# Time for epoch 916 is 0.08734893798828125 sec
# 915
# end of epoch
# Time for epoch 917 is 0.07388448715209961 sec
# 916
# end of epoch
# Time for epoch 918 is 0.08055901527404785 sec
# 917
# end of epoch
# Time for epoch 919 is 0.07766556739807129 sec
# 918
# end of epoch
# Time for epoch 920 is 0.07627034187316895 sec
# 919
# end of epoch
# Time for epoch 921 is 0.07756829261779785 sec
# 920
# end of epoch
# Time for epoch 922 is 0.07476949691772461 sec
# 921
# end of epoch
# Time for epoch 923 is 0.07427430152893066 sec
# 922
# end of epoch
# Time for epoch 924 is 0.07764816284179688 sec
# 923
# end of epoch
# Time for epoch 925 is 0.07546424865722656 sec
# 924
# end of epoch
# Time for epoch 926 is 0.08822822570800781 sec
# 925
# end of epoch
# Time for epoch 927 is 0.08871579170227051 sec
# 926
# end of epoch
# Time for epoch 928 is 0.08529329299926758 sec
# 927
# end of epoch
# Time for epoch 929 is 0.0916585922241211 sec
# 928
# end of epoch
# Time for epoch 930 is 0.07740259170532227 sec
# 929
# end of epoch
# Time for epoch 931 is 0.07873797416687012 sec
# 930
# end of epoch
# Time for epoch 932 is 0.0928347110748291 sec
# 931
# end of epoch
# Time for epoch 933 is 0.07844710350036621 sec
# 932
# end of epoch
# Time for epoch 934 is 0.09084296226501465 sec
# 933
# end of epoch
# Time for epoch 935 is 0.07931065559387207 sec
# 934
# end of epoch
# Time for epoch 936 is 0.08948755264282227 sec
# 935
# end of epoch
# Time for epoch 937 is 0.09094500541687012 sec
# 936
# end of epoch
# Time for epoch 938 is 0.08240914344787598 sec
# 937
# end of epoch
# Time for epoch 939 is 0.072845458984375 sec
# 938
# end of epoch
# Time for epoch 940 is 0.07128286361694336 sec
# 939
# end of epoch
# Time for epoch 941 is 0.07370185852050781 sec
# 940
# end of epoch
# Time for epoch 942 is 0.07449769973754883 sec
# 941
# end of epoch
# Time for epoch 943 is 0.09929490089416504 sec
# 942
# end of epoch
# Time for epoch 944 is 0.07526063919067383 sec
# 943
# end of epoch
# Time for epoch 945 is 0.08543682098388672 sec
# 944
# end of epoch
# Time for epoch 946 is 0.07386612892150879 sec
# 945
# end of epoch
# Time for epoch 947 is 0.0803380012512207 sec
# 946
# end of epoch
# Time for epoch 948 is 0.073028564453125 sec
# 947
# end of epoch
# Time for epoch 949 is 0.07668256759643555 sec
# 948
# end of epoch
# Time for epoch 950 is 0.08233189582824707 sec
# 949
# end of epoch
# Time for epoch 951 is 0.07203078269958496 sec
# 950
# end of epoch
# Time for epoch 952 is 0.0737605094909668 sec
# 951
# end of epoch
# Time for epoch 953 is 0.07286715507507324 sec
# 952
# end of epoch
# Time for epoch 954 is 0.0727851390838623 sec
# 953
# end of epoch
# Time for epoch 955 is 0.07276487350463867 sec
# 954
# end of epoch
# Time for epoch 956 is 0.07378387451171875 sec
# 955
# end of epoch
# Time for epoch 957 is 0.0764319896697998 sec
# 956
# end of epoch
# Time for epoch 958 is 0.09223270416259766 sec
# 957
# end of epoch
# Time for epoch 959 is 0.08058404922485352 sec
# 958
# end of epoch
# Time for epoch 960 is 0.07416772842407227 sec
# 959
# end of epoch
# Time for epoch 961 is 0.08905911445617676 sec
# 960
# end of epoch
# Time for epoch 962 is 0.07124447822570801 sec
# 961
# end of epoch
# Time for epoch 963 is 0.07631897926330566 sec
# 962
# end of epoch
# Time for epoch 964 is 0.07648992538452148 sec
# 963
# end of epoch
# Time for epoch 965 is 0.0766134262084961 sec
# 964
# end of epoch
# Time for epoch 966 is 0.07476401329040527 sec
# 965
# end of epoch
# Time for epoch 967 is 0.09442758560180664 sec
# 966
# end of epoch
# Time for epoch 968 is 0.07470321655273438 sec
# 967
# end of epoch
# Time for epoch 969 is 0.07342386245727539 sec
# 968
# end of epoch
# Time for epoch 970 is 0.07285809516906738 sec
# 969
# end of epoch
# Time for epoch 971 is 0.09063720703125 sec
# 970
# end of epoch
# Time for epoch 972 is 0.07668590545654297 sec
# 971
# end of epoch
# Time for epoch 973 is 0.07743167877197266 sec
# 972
# end of epoch
# Time for epoch 974 is 0.07677125930786133 sec
# 973
# end of epoch
# Time for epoch 975 is 0.07598328590393066 sec
# 974
# end of epoch
# Time for epoch 976 is 0.08767986297607422 sec
# 975
# end of epoch
# Time for epoch 977 is 0.07737088203430176 sec
# 976
# end of epoch
# Time for epoch 978 is 0.07381105422973633 sec
# 977
# end of epoch
# Time for epoch 979 is 0.0733346939086914 sec
# 978
# end of epoch
# Time for epoch 980 is 0.07971501350402832 sec
# 979
# end of epoch
# Time for epoch 981 is 0.07779312133789062 sec
# 980
# end of epoch
# Time for epoch 982 is 0.0753011703491211 sec
# 981
# end of epoch
# Time for epoch 983 is 0.0845484733581543 sec
# 982
# end of epoch
# Time for epoch 984 is 0.07145047187805176 sec
# 983
# end of epoch
# Time for epoch 985 is 0.07471656799316406 sec
# 984
# end of epoch
# Time for epoch 986 is 0.07985734939575195 sec
# 985
# end of epoch
# Time for epoch 987 is 0.07342386245727539 sec
# 986
# end of epoch
# Time for epoch 988 is 0.07450246810913086 sec
# 987
# end of epoch
# Time for epoch 989 is 0.0747990608215332 sec
# 988
# end of epoch
# Time for epoch 990 is 0.07347655296325684 sec
# 989
# end of epoch
# Time for epoch 991 is 0.0775444507598877 sec
# 990
# end of epoch
# Time for epoch 992 is 0.07224035263061523 sec
# 991
# end of epoch
# Time for epoch 993 is 0.08606219291687012 sec
# 992
# end of epoch
# Time for epoch 994 is 0.07380938529968262 sec
# 993
# end of epoch
# Time for epoch 995 is 0.07522940635681152 sec
# 994
# end of epoch
# Time for epoch 996 is 0.0733187198638916 sec
# 995
# end of epoch
# Time for epoch 997 is 0.07854604721069336 sec
# 996
# end of epoch
# Time for epoch 998 is 0.07739520072937012 sec
# 997
# end of epoch
# Time for epoch 999 is 0.08000326156616211 sec
# 998
# end of epoch
# Time for epoch 1000 is 0.07416343688964844 sec
# 999
# end of epoch

# %%
# DO NOT EDIT
title = "positive_data"
epoch_ckp = EPOCHS - 1
checkpoint_name = checkpoint_dir + "/ckpt__" + str(title) + "__epoch=" + str(epoch_ckp) + "__-" + str(EPOCHS)
# RESTORE CHECKPOINT to variables defined on it
checkpoint.restore(checkpoint_name)

# %%
Z_DIM=4
N_pos = 500
tf.random.set_seed(0)
noise_GEN = tf.random.normal([N_pos, Z_DIM])
# labels_GEN = set for CGAN
data_pos_GEN = generator(noise_GEN, training=False)

# %%
import numpy
proto_tensor = tf.make_tensor_proto(data_pos_GEN)  # convert `tensor a` to a proto tensor
data2 = tf.make_ndarray(proto_tensor) #convert tf tesor to np array
print(data2.shape)
# Out:
# (500, 4)

# %%
import pandas as pd 
pd.DataFrame(data2).to_csv("/content/drive/MyDrive/Privacy/DPGAN_pos_NEWdata.csv")
